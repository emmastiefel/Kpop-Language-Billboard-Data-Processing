# %%
import pandas as pd
import time
import numpy as np
import lyricsgenius

# %%
genius = lyricsgenius.Genius('KQ5oZoRnw1ea0YwPjOeDFacmn37UlUDjp8DGKlj7pfgDsIXJYfOz00skKmR8hqhR')

# %%
translations = genius.search_artist('Genius English Translations', sort='popularity', max_songs=1)
# Out:
# e Pons - Celoso (English Translation)"
# "BTS (방탄소년단) - Skit (English Translation)" is not valid. Skipping.
# Song 178: "BTS - 잡아줘 (Hold Me Tight) (English Translation)"
# Song 179: "BTS - Reflection (English Translation)"
# Song 180: "Bad Bunny - BYE ME FUI (English Translation)"
# Song 181: "BTS - 고엽 (Autumn Leaves/Dead Leaves) (English Translation)"
# Song 182: "IU -  이런 엔딩 (Ending Scene) (English Translation)"
# Song 183: "Ozuna - Dile Que Tú Me Quieres (English Translation)"
# Song 184: "MORGENSHTERN - ICE (English Translation)"
# Song 185: "Bad Bunny - Soy Peor (English Translation)"
# Song 186: "Kyary Pamyu Pamyu - PONPONPON (English Translation)"
# Song 187: "Shakira - Chantaje (English Translation)"
# Song 188: "BTS - So Far Away (Suga, Jin, Jungkook Ver.) (English Translation)"
# Song 189: "Agust D - 저 달 (Moonlight) (English Translation)"
# Song 190: "NCT Dream - Drippin’ (English Translation)"
# Song 191: "BTS - “Outro: Her” (English Translation)"
# ...

# %%
translations.songs
# Out:
# YEOL & PUNCH – Stay With Me (English Translation)', 'Genius English Translations'),
#  ('CHUNGHA - 벌써 12시 (Gotta Go) (English Translation)', 'Genius English Translations'),
#  ('BTS - Serendipity (Full Length Edition) (English Translation)', 'Genius English Translations'),
#  ('BTS & Charli XCX - Dream Glow (English Translation)', 'Genius English Translations'),
#  ('Rammstein - ZEIG DICH (English Translation)', 'Genius English Translations'),
#  ('IU - Love Poem (English Translation)', 'Genius English Translations'),
#  ('Maluma & The Weeknd - Hawái (Remix) [English Translation]', 'Genius English Translations'),
#  ('Jin (BTS) - 이 밤 (Tonight/This Night) [English Translation]', 'Genius English Translations'),
#  ('BTS - IDOL (Remix) ft. Nicki Minaj (English Translation)', 'Genius English Translations'),
#  ('BTS & Juice WRLD - All Night (English Translation)', 'Genius English Translations'),
# ...

# %%
translations.save_lyrics()
# Out:
# Wrote `Lyrics_GeniusEnglishTranslations.json`

# %%
for song in translations.songs:
    print(song)
    print(song.lyrics[:50])
# Out:
#
#     Oh gosh so crazy (Oh gosh)
#     Yeah, I’m an emotional girl
#     I fall in love so easily
#     (Yeah ...
# Uhm yeah yah
#
# Oh gosh so crazy (Oh gosh)
# Yeah, I’m
# "Lee Sora - 신청곡 (Song Request) (ft. SUGA) (English Translation)" by Genius English Translations:
#     [Verse 1: Lee Sora]
#     It’s raining again outside the window
#     These moments make me think of you
#     I can’t...
# [Verse 1: Lee Sora]
# It’s raining again outside the
# "Stray Kids - Easy (English Translation)" by Genius English Translations:
#     [Verse 1: Han, Hyunjin, Felix]
#     I do what I want
#     Whatever I do or don't, I just take a rest
#     We gonna ...
# [Verse 1: Han, Hyunjin, Felix]
# I do what I want
# Wh
# "Bad Bunny & Anuel AA - Está Cabrón Ser Yo (English Translation)" by Genius English Translations:
#     [Intro: Anuel AA]
#     Brr
#     It's Payday, fellas
#     Yo Hago Lo Que Me Da La Gana, did you hear cocksucker?
#     Fra...
# [Intro: Anuel AA]
# Brr
# It's Payday, fellas
# ...

# %%
translations.song("Paldogangsan")
# Out:
# Searching for "Paldogangsan" by Genius English Translations...
# Done.
# ('팔도강산 Paldogangsan (Satoori Rap) (English Translation)', 'Genius English Translations')
