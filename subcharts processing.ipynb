# %%
import pandas as pd
from datetime import timedelta
from datetime import datetime
import numpy as np
import matplotlib.pyplot as plt

import lyricsgenius
from fuzzywuzzy import fuzz

# %%
#function to convert strings to dates :)
def string_to_datetime(string):
    result = datetime.strptime(string, "%Y-%m-%d")       
    return result

# %%
#read in radio, streaming, sales data
radio = pd.read_csv('subcharts - Radio_Kpop.csv')
streaming = pd.read_csv('subcharts - Streaming_Kpop.csv')
sales = pd.read_csv('subcharts - Sales_Kpop.csv')
hot100 = pd.read_csv('BBSHRK - Spotify_BBH100_Kpop.csv')

# %%
##standardize artist and song names 
for chart in [sales, streaming, radio, hot100]:
    #drop random unnamed columns
    drop_columns = [c for c in chart.columns if 'Unnamed' in c ]
    chart.drop(columns=drop_columns, inplace=True)

    #remove wiki citations, standardize whitespace, remove quotation marks
    #regex patterns and replacement strings
    regex_pats = [[r"(\[\d+\])", ""], [r"(\s)", " "], [r"(\")", ""]]
    for pat in regex_pats:
        chart["artist"] = chart["artist"].str.replace(pat[0], pat[1])
        chart["song_title"] = chart["song_title"].str.replace(pat[0], pat[1])
        
    #separate out main artist: split by feat. and and
    chart['main_artist'] = chart['artist'].str.replace(r"(feat.*)", '')
    #handle suga/agust d specifically because this errror comes up a lot
    chart['main_artist'] = ['Agust D' if 'Agust D' in a else a for a in chart['main_artist']]
    chart['main_artist'] = chart['main_artist'].str.replace(r"(and.*)", '')
    chart['main_artist'] = chart['main_artist'].str.replace(r"(,.*)", '')
    chart['main_artist'] = chart['main_artist'].str.replace(r"(&.*)", '')
    chart['main_artist'] = chart['main_artist'].str.replace(r"(:.*)", '')

    #remove parentheticals from song name and artist name
    chart['search_title'] = chart['song_title'].str.replace(r"(\(.*\))", "")
    chart['main_artist'] = chart['main_artist'].str.replace(r"(\(.*\))", "")

    #strip out whitespace
    chart['search_title'] = chart['search_title'].str.strip()
    chart['main_artist'] = chart['main_artist'].str.strip()

    #convert chart_date to datetime object
    #chart["chart_date"] = [string_to_datetime(d) for d in chart["chart_date"]]

# %%
## standardize peak positions, take first when multiple are listed
for i, r in sales.iterrows():
    try:
        new_pos = int(r['peak_position'])
    except:
        new_pos = int(r['peak_position'].split(' ')[0])
    sales.at[i, 'peak_position'] = new_pos

# %%
sales.rename(columns={'chart_date':'chart_date_sales', 'peak_position':'peak_position_sales', 'chart_weeks':'chart_weeks_sales'}, inplace=True)
streaming.rename(columns={'chart_date':'chart_date_streaming', 'peak_position':'peak_position_streaming', 'chart_weeks':'chart_weeks_streaming'}, inplace=True)
radio.rename(columns={'chart_date':'chart_date_radio','peak_position':'peak_position_radio', 'chart_weeks':'chart_weeks_radio'}, inplace=True)

# %%
## merge other charts into the hot 100 data
hot100_radio = hot100.merge(radio, how='outer', on=['search_title', 'main_artist'])
hot100_radio_streaming = hot100_radio.merge(streaming, how='outer', on=['search_title', 'main_artist'])
hot100_radio_streaming_sales = hot100_radio_streaming.merge(sales, how='outer', on=['search_title', 'main_artist'])

# %%
# identify all songs missing lyrics (not on hot 100)
to_fill = hot100_radio_streaming_sales.loc[hot100_radio_streaming_sales['translated_lyrics'].isnull()]

# %%
### scrape original lyrics from genius

genius = lyricsgenius.Genius('wxBLY4fHewydC6H8GBlsicom4El7Gyo6vKfejjTR9ojLfNUslIjcmvZ9iYVGi5RC')

for i, r in to_fill.iterrows():
    this_song = genius.search_song(r['search_title'], r['main_artist'])

    #continue if it returns a result
    if this_song:
        #partial ratio threshold to prevent mismatches
        title_similarity = fuzz.partial_ratio(r['search_title'].lower(), this_song.title.lower())
        artist_similarity = fuzz.partial_ratio(r['main_artist'].lower(), this_song.artist.lower())
        

        #if similarity is above threshold, store lyrics + url
        if title_similarity > 60 and artist_similarity > 60:
            print("MATCHED:")
            print(r['search_title'], r['main_artist'], " | ", this_song.title, this_song.artist)
            hot100_radio_streaming_sales.at[i, 'original_lyrics'] = this_song.lyrics
            hot100_radio_streaming_sales.at[i, 'Original URL'] = this_song.url
# Out:
# Searching for "Euphoria" by BTS...
# Done.
# MATCHED:
# Euphoria BTS  |  Euphoria BTS (방탄소년단)
# Searching for "I'm Fine" by BTS...
# Done.
# MATCHED:
# I'm Fine BTS  |  I’m Fine BTS (방탄소년단)
# Searching for "Epiphany" by BTS...
# Done.
# MATCHED:
# Epiphany BTS  |  Epiphany BTS (방탄소년단)
# Searching for "Trivia: Seesaw" by BTS...
# Done.
# MATCHED:
# Trivia: Seesaw BTS  |  Trivia 轉: Seesaw BTS (방탄소년단)
# Searching for "Answer: Love Myself" by BTS...
# Done.
# MATCHED:
# Answer: Love Myself BTS  |  Answer: Love Myself BTS (방탄소년단)
# Searching for "Trivia: Just Dance" by BTS...
# Done.
# MATCHED:
# Trivia: Just Dance BTS  |  Trivia 起: Just Dance BTS (방탄소년단)
# Searching for "Serendipity" by BTS...
# Done.
# Searching for "Trivia: Love" by BTS...
# Done.
# MATCHED:
# Trivia: Love BTS  |  Trivia 承: Love BTS (방탄소년단)
# Searching for "Pop/Stars" by K/DA...
# Done.
# MATCHED:
# Pop/Stars K/DA  |  POP/STARS K/DA
# Searching for "2! 3!" by BTS...
# Done.
# MATCHED:
# 2! 3! BTS  |  둘! 셋! (그래도 좋은 날이 더 많기를) [2! 3! (Still Wishing For More Good Days)] BTS (방탄소년단)
# Searching for "Make It Right" by BTS...
# Done.
# MATCHED:
# Make It Right BTS  |  Make It Right BTS (방탄소년단)
# Searching for "Mikrokosmos" by BTS...
# Done.
# MATCHED:
# Mikrokosmos BTS  |  소우주 (Mikrokosmos) BTS (방탄소년단)
# Searching for "Home" by BTS...
# Done.
# MATCHED:
# Home BTS  |  HOME BTS (방탄소년단)
# Searching for "Dionysus" by BTS...
# Done.
# MATCHED:
# Dionysus BTS  |  Dionysus BTS (방탄소년단)
# Searching for "Jamais Vu" by BTS...
# Done.
# MATCHED:
# Jamais Vu BTS  |  Jamais Vu BTS (방탄소년단)
# Searching for "Intro: Persona" by BTS...
# Done.
# MATCHED:
# Intro: Persona BTS  |  Intro: Persona BTS (방탄소년단)
# Searching for "Dream Glow" by BTS...
# Done.
# MATCHED:
# Dream Glow BTS  |  Dream Glow BTS & Charli XCX
# Searching for "A Brand New Day" by BTS...
# Done.
# MATCHED:
# A Brand New Day BTS  |  A Brand New Day BTS & Zara Larsson
# Searching for "All Night" by BTS...
# Done.
# MATCHED:
# All Night BTS  |  All Night BTS & Juice WRLD
# Searching for "Heartbeat" by BTS...
# Done.
# MATCHED:
# Heartbeat BTS  |  Heartbeat BTS (방탄소년단)
# Searching for "Lights" by BTS...
# Done.
# MATCHED:
# Lights BTS  |  Lights BTS (방탄소년단)
# Searching for "Suga's Interlude" by Halsey...
# Done.
# MATCHED:
# Suga's Interlude Halsey  |  SUGA’s Interlude Halsey, SUGA & BTS
# Searching for "Winter Flower" by Younha...
# Done.
# Searching for "Friends" by BTS...
# Done.
# MATCHED:
# Friends BTS  |  친구 (Friends) BTS (방탄소년단)
# Searching for "Louder Than Bombs" by BTS...
# Done.
# MATCHED:
# Louder Than Bombs BTS  |  Louder than bombs BTS (방탄소년단)
# Searching for "Inner Child" by BTS...
# Done.
# MATCHED:
# Inner Child BTS  |  Inner Child BTS (방탄소년단)
# Searching for "We Are Bulletproof: The Eternal" by BTS...
# Done.
# MATCHED:
# We Are Bulletproof: The Eternal BTS  |  We Are Bulletproof : The Eternal BTS (방탄소년단)
# Searching for "Ugh!" by BTS...
# Done.
# MATCHED:
# Ugh! BTS  |  욱 (UGH!) BTS (방탄소년단)
# Searching for "00:00" by BTS...
# Done.
# Searching for "Moon" by BTS...
# Done.
# MATCHED:
# Moon BTS  |  Moon BTS (방탄소년단)
# Searching for "Interlude: Shadow" by BTS...
# Done.
# MATCHED:
# Interlude: Shadow BTS  |  Interlude: Shadow BTS (방탄소년단)
# Searching for "Outro: Ego" by BTS...
# Done.
# MATCHED:
# Outro: Ego BTS  |  Outro: Ego BTS (방탄소년단)
# Searching for "Respect" by BTS...
# Done.
# MATCHED:
# Respect BTS  |  Respect BTS (방탄소년단)
# Searching for "Who" by Lauv...
# Done.
# MATCHED:
# Who Lauv  |  Who Lauv
# Searching for "Sweet Night" by V...
# Done.
# MATCHED:
# Sweet Night V  |  Sweet Night V (BTS)
# Searching for "Eight" by IU...
# Done.
# MATCHED:
# Eight IU  |  에잇 (eight) IU (아이유)
# Searching for "Strange" by Agust D...
# Done.
# MATCHED:
# Strange Agust D  |  이상하지 않은가 (Strange) Agust D
# Searching for "Burn It" by Agust D...
# Done.
# MATCHED:
# Burn It Agust D  |  Burn It Agust D
# Searching for "What Do You Think?" by Agust D...
# Done.
# MATCHED:
# What Do You Think? Agust D  |  어떻게 생각해? (What do you think?) Agust D
# Searching for "Moonlight" by Agust D...
# Done.
# MATCHED:
# Moonlight Agust D  |  저 달 (Moonlight) Agust D
# Searching for "People" by Agust D...
# Done.
# MATCHED:
# People Agust D  |  사람 (People) Agust D
# Searching for "28" by Agust D...
# Done.
# MATCHED:
# 28 Agust D  |  점점 어른이 되나봐 (28) Agust D
# Searching for "Dear My Friend" by Agust D...
# Done.
# MATCHED:
# Dear My Friend Agust D  |  어땠을까 (Dear my friend) Agust D
# Searching for "Interlude: Set Me Free" by Agust D...
# Done.
# MATCHED:
# Interlude: Set Me Free Agust D  |  Interlude: Set me free Agust D
# Searching for "Honsool" by Agust D...
# Done.
# MATCHED:
# Honsool Agust D  |  혼술 (Honsool) Agust D
# Searching for "Stay Gold" by BTS...
# Done.
# MATCHED:
# Stay Gold BTS  |  Stay Gold BTS (방탄소년단)
# Searching for "Your Eyes Tell" by BTS...
# Done.
# MATCHED:
# Your Eyes Tell BTS  |  Your eyes tell BTS (방탄소년단)
# Searching for "The Baddest" by K/DA...
# Done.
# MATCHED:
# The Baddest K/DA  |  THE BADDEST K/DA
# Searching for "Blueberry Eyes" by Max Schneider...
# Done.
# MATCHED:
# Blueberry Eyes Max Schneider  |  Blueberry Eyes MAX
# Searching for "G.B.T.B." by Verivery...
# Done.
# MATCHED:
# G.B.T.B. Verivery  |  G.B.T.B. VERIVERY

# %%
##iterate through all songs to scrape translated lyrics
for i, r in to_fill.iterrows():

    artist = r['main_artist']
    title = r['search_title']
    this_song = genius.search_song(artist + ' - ' + title + ' (English Translation)', 'Genius English Translations')

    #continue if it returns a result
    if this_song:
        #partial ratio threshold to prevent mismatches
        similarity = fuzz.partial_ratio((artist + ' - ' + title + ' (English Translation)').lower(), this_song.title.lower())
        

        #if similarity is above threshold, store lyrics + url
        if similarity > 60:
            print('MATCHED:')
            print((artist + ' - ' + title), this_song.title)
            hot100_radio_streaming_sales.at[i, 'translated_lyrics'] = this_song.lyrics
            hot100_radio_streaming_sales.at[i, 'English Translation URL'] = this_song.url
# Out:
# Searching for "BTS - Euphoria (English Translation)" by Genius English Translations...
# Done.
# MATCHED:
# BTS - Euphoria BTS - Euphoria (English Translation)
# Searching for "BTS - I'm Fine (English Translation)" by Genius English Translations...
# Done.
# MATCHED:
# BTS - I'm Fine BTS - I’m Fine (English Translation)
# Searching for "BTS - Epiphany (English Translation)" by Genius English Translations...
# Done.
# MATCHED:
# BTS - Epiphany BTS - Epiphany (English Translation)
# Searching for "BTS - Trivia: Seesaw (English Translation)" by Genius English Translations...
# Done.
# MATCHED:
# BTS - Trivia: Seesaw BTS - Trivia 轉: Seesaw (English Translation)
# Searching for "BTS - Answer: Love Myself (English Translation)" by Genius English Translations...
# Done.
# MATCHED:
# BTS - Answer: Love Myself BTS - Answer: Love Myself (English Translation)
# Searching for "BTS - Trivia: Just Dance (English Translation)" by Genius English Translations...
# Done.
# MATCHED:
# BTS - Trivia: Just Dance BTS - Trivia 起: Just Dance (English Translation)
# Searching for "BTS - Serendipity (English Translation)" by Genius English Translations...
# Done.
# MATCHED:
# BTS - Serendipity BTS - Serendipity (Full Length Edition) (English Translation)
# Searching for "BTS - Trivia: Love (English Translation)" by Genius English Translations...
# Done.
# MATCHED:
# BTS - Trivia: Love BTS - Trivia 承: Love (English Translation)
# Searching for "K/DA - Pop/Stars (English Translation)" by Genius English Translations...
# Done.
# MATCHED:
# K/DA - Pop/Stars K/DA - POP/STARS (English Translation)
# Searching for "BTS - 2! 3! (English Translation)" by Genius English Translations...
# Done.
# MATCHED:
# BTS - 2! 3! BTS - 둘! 셋! (그래도 좋은 날이 더 많기를) [2! 3! (Still Wishing For More Good Days)] (English Translation)
# Searching for "BTS - Make It Right (English Translation)" by Genius English Translations...
# Done.
# MATCHED:
# BTS - Make It Right BTS - Make It Right (English Translation)
# Searching for "BTS - Mikrokosmos (English Translation)" by Genius English Translations...
# Done.
# MATCHED:
# BTS - Mikrokosmos BTS - 소우주 (Mikrokosmos) (English Translation)
# Searching for "BTS - Home (English Translation)" by Genius English Translations...
# Done.
# MATCHED:
# BTS - Home BTS - HOME (English Translation)
# Searching for "BTS - Dionysus (English Translation)" by Genius English Translations...
# Done.
# MATCHED:
# BTS - Dionysus BTS - Dionysus (English Translation)
# Searching for "BTS - Jamais Vu (English Translation)" by Genius English Translations...
# Done.
# MATCHED:
# BTS - Jamais Vu BTS - Jamais Vu (English Translation)
# Searching for "BTS - Intro: Persona (English Translation)" by Genius English Translations...
# Done.
# MATCHED:
# BTS - Intro: Persona BTS - Intro: Persona (English Translation)
# Searching for "BTS - Dream Glow (English Translation)" by Genius English Translations...
# Done.
# MATCHED:
# BTS - Dream Glow BTS & Charli XCX - Dream Glow (English Translation)
# Searching for "BTS - A Brand New Day (English Translation)" by Genius English Translations...
# Done.
# MATCHED:
# BTS - A Brand New Day BTS & Zara Larsson - A Brand New Day (English Translation)
# Searching for "BTS - All Night (English Translation)" by Genius English Translations...
# Done.
# MATCHED:
# BTS - All Night BTS & Juice WRLD - All Night (English Translation)
# Searching for "BTS - Heartbeat (English Translation)" by Genius English Translations...
# Done.
# MATCHED:
# BTS - Heartbeat BTS - Heartbeat (English Translation)
# Searching for "BTS - Lights (English Translation)" by Genius English Translations...
# Done.
# MATCHED:
# BTS - Lights BTS - Lights (English Translation)
# Searching for "Halsey - Suga's Interlude (English Translation)" by Genius English Translations...
# Done.
# MATCHED:
# Halsey - Suga's Interlude Halsey, SUGA & BTS - SUGA’s Interlude (English Translation)
# Searching for "Younha - Winter Flower (English Translation)" by Genius English Translations...
# Done.
# MATCHED:
# Younha - Winter Flower YOUNHA - Winter Flower (雪中梅) ft. RM (English Translation)
# Searching for "BTS - Friends (English Translation)" by Genius English Translations...
# Done.
# MATCHED:
# BTS - Friends BTS - 친구 (Friends) (English Translation)
# Searching for "BTS - Louder Than Bombs (English Translation)" by Genius English Translations...
# Done.
# MATCHED:
# BTS - Louder Than Bombs BTS - Louder than bombs (English Translation)
# Searching for "BTS - Inner Child (English Translation)" by Genius English Translations...
# Done.
# MATCHED:
# BTS - Inner Child BTS - Inner Child (English Translation)
# Searching for "BTS - We Are Bulletproof: The Eternal (English Translation)" by Genius English Translations...
# Done.
# MATCHED:
# BTS - We Are Bulletproof: The Eternal BTS - We Are Bulletproof: The Eternal (English Translation)
# Searching for "BTS - Ugh! (English Translation)" by Genius English Translations...
# Done.
# MATCHED:
# BTS - Ugh! BTS - 욱 (UGH!) (English Translation)
# Searching for "BTS - 00:00 (English Translation)" by Genius English Translations...
# Done.
# MATCHED:
# BTS - 00:00 BTS - 00:00 (Zero O’Clock) (English Translation)
# Searching for "BTS - Moon (English Translation)" by Genius English Translations...
# Done.
# MATCHED:
# BTS - Moon BTS - Moon (English Translation)
# Searching for "BTS - Interlude: Shadow (English Translation)" by Genius English Translations...
# Done.
# MATCHED:
# BTS - Interlude: Shadow BTS - Interlude: Shadow (English Translation)
# Searching for "BTS - Outro: Ego (English Translation)" by Genius English Translations...
# Done.
# MATCHED:
# BTS - Outro: Ego BTS - Outro: Ego (English Translation)
# Searching for "BTS - Respect (English Translation)" by Genius English Translations...
# Done.
# MATCHED:
# BTS - Respect BTS - Respect (English Translation)
# Searching for "Lauv - Who (English Translation)" by Genius English Translations...
# Done.
# Searching for "V - Sweet Night (English Translation)" by Genius English Translations...
# Done.
# Searching for "IU - Eight (English Translation)" by Genius English Translations...
# Done.
# MATCHED:
# IU - Eight IU - 에잇 (eight) ft. SUGA (English Translation)
# Searching for "Agust D - Strange (English Translation)" by Genius English Translations...
# Done.
# MATCHED:
# Agust D - Strange Agust D - 이상하지않은가 (Strange) ft. RM (English Translation)
# Searching for "Agust D - Burn It (English Translation)" by Genius English Translations...
# Done.
# MATCHED:
# Agust D - Burn It Agust D - Burn It ft. MAX (English Translation)
# Searching for "Agust D - What Do You Think? (English Translation)" by Genius English Translations...
# Done.
# MATCHED:
# Agust D - What Do You Think? Agust D - 어떻게 생각해? (What do you think?) (English Translation)
# Searching for "Agust D - Moonlight (English Translation)" by Genius English Translations...
# Done.
# MATCHED:
# Agust D - Moonlight Agust D - 저 달 (Moonlight) (English Translation)
# Searching for "Agust D - People (English Translation)" by Genius English Translations...
# Done.
# MATCHED:
# Agust D - People Agust D - 사람 (People) (English Translation)
# Searching for "Agust D - 28 (English Translation)" by Genius English Translations...
# Done.
# MATCHED:
# Agust D - 28 Agust D - 점점 어른이 되나봐 (28) ft. NiiHWA (English Translation)
# Searching for "Agust D - Dear My Friend (English Translation)" by Genius English Translations...
# Done.
# MATCHED:
# Agust D - Dear My Friend Agust D - 어땠을까 (Dear my friend) ft. Kim Jong Wan (English Translation)
# Searching for "Agust D - Interlude: Set Me Free (English Translation)" by Genius English Translations...
# Done.
# MATCHED:
# Agust D - Interlude: Set Me Free Agust D - Interlude: Set me free (English Translation)
# Searching for "Agust D - Honsool (English Translation)" by Genius English Translations...
# Done.
# MATCHED:
# Agust D - Honsool Agust D - 혼술 (Honsool) (English Translation)
# Searching for "BTS - Stay Gold (English Translation)" by Genius English Translations...
# Done.
# MATCHED:
# BTS - Stay Gold BTS - Stay Gold (English Translation)
# Searching for "BTS - Your Eyes Tell (English Translation)" by Genius English Translations...
# Done.
# MATCHED:
# BTS - Your Eyes Tell BTS - Your eyes tell (English Translation)
# Searching for "K/DA - The Baddest (English Translation)" by Genius English Translations...
# Done.
# MATCHED:
# K/DA - The Baddest K/DA - THE BADDEST (English Translation)
# Searching for "Max Schneider - Blueberry Eyes (English Translation)" by Genius English Translations...
# No results found for: 'Max Schneider - Blueberry Eyes (English Translation) Genius English Translations'
# Searching for "Verivery - G.B.T.B. (English Translation)" by Genius English Translations...
# No results found for: 'Verivery - G.B.T.B. (English Translation) Genius English Translations'

# %%
no_original = hot100_radio_streaming_sales.loc[hot100_radio_streaming_sales['original_lyrics'].isnull()]
no_original['search_title']
# Out:
# Series([], Name: search_title, dtype: object)

# %%
#### original lyrics mistakes

## missed Serendipity
#this_song = genius.search_song("Serendipity Full Length", "BTS")
#index = hot100_radio_streaming_sales.loc[hot100_radio_streaming_sales['search_title'] == 'Serendipity'].index[0]
#hot100_radio_streaming_sales.at[index, 'Original URL'] = this_song.url
#hot100_radio_streaming_sales.at[index, 'original_lyrics'] = this_song.lyrics

## missed winter flower
#this_song = genius.search_song("Winter Flower (雪中梅)", "Younha")
#index = hot100_radio_streaming_sales.loc[hot100_radio_streaming_sales['search_title'] == 'Winter Flower'].index[0]
#hot100_radio_streaming_sales.at[index, 'Original URL'] = this_song.url
#hot100_radio_streaming_sales.at[index, 'original_lyrics'] = this_song.lyrics

## missed zero o clock
this_song = genius.search_song("Zero O'Clock", "BTS")
index = hot100_radio_streaming_sales.loc[hot100_radio_streaming_sales['search_title'] == '00:00'].index[0]
hot100_radio_streaming_sales.at[index, 'Original URL'] = this_song.url
hot100_radio_streaming_sales.at[index, 'original_lyrics'] = this_song.lyrics
# Out:
# Searching for "Zero O'Clock" by BTS...
# Done.

# %%
no_translated = hot100_radio_streaming_sales.loc[hot100_radio_streaming_sales['translated_lyrics'].isnull()]
no_translated['search_title']
# Out:
# Series([], Name: search_title, dtype: object)

# %%
#### translated lyrics mistakes

## sweet night is entirely in english
sn_index = hot100_radio_streaming_sales.loc[hot100_radio_streaming_sales['search_title'] == 'Sweet Night'].index[0]
hot100_radio_streaming_sales.at[sn_index, 'English Translation URL'] = hot100_radio_streaming_sales.at[sn_index, 'Original URL']
hot100_radio_streaming_sales.at[sn_index, 'translated_lyrics'] = hot100_radio_streaming_sales.at[sn_index, 'original_lyrics']

## who is also entirely in english
who_index = hot100_radio_streaming_sales.loc[hot100_radio_streaming_sales['search_title'] == 'Who'].index[0]
hot100_radio_streaming_sales.at[who_index, 'English Translation URL'] = hot100_radio_streaming_sales.at[who_index, 'Original URL']
hot100_radio_streaming_sales.at[who_index, 'translated_lyrics'] = hot100_radio_streaming_sales.at[who_index, 'original_lyrics']

# %%
## missed translation for blueberry eyes
bbe_genius = genius.search_song("MAX - Blueberry Eyes ft. SUGA (English Translation)", "Genius English Translations")
bbe_index = hot100_radio_streaming_sales.loc[hot100_radio_streaming_sales['search_title'] == 'Blueberry Eyes'].index[0]
hot100_radio_streaming_sales.at[bbe_index, 'English Translation URL'] = bbe_genius.url
hot100_radio_streaming_sales.at[bbe_index, 'translated_lyrics'] = bbe_genius.lyrics
# Out:
# Searching for "MAX - Blueberry Eyes ft. SUGA (English Translation)" by Genius English Translations...
# Done.

# %%
## genius does not have english translaltion of gbtb
gbtb_index = hot100_radio_streaming_sales.loc[hot100_radio_streaming_sales['search_title'] == 'G.B.T.B.'].index[0]
hot100_radio_streaming_sales.at[gbtb_index, 'English Translation URL'] = 'https://lyricstranslate.com/en/gbtb-gbtb.html'
hot100_radio_streaming_sales.at[gbtb_index, 'translated_lyrics'] = open("Manual Lyrics/GBTB.txt", "r").read()

# %%
#### re-process data now that it is all collected

#scale spotify valence values
#hot100_radio_streaming_sales['scaled_valence'] = [s*2 - 1 for s in hot100_radio_streaming_sales['valence']]

##process text 
#remove romanized lyrics that are in some genius pages
hot100_radio_streaming_sales["original_lyrics"] = [lyrics.split("Romanization")[0] for lyrics in hot100_radio_streaming_sales["original_lyrics"]]

#get rid of bracketed sections like verse indicators
hot100_radio_streaming_sales["original_lyrics"] = hot100_radio_streaming_sales["original_lyrics"].str.replace(r"(\[.*\])", "")
hot100_radio_streaming_sales["translated_lyrics"] = hot100_radio_streaming_sales["translated_lyrics"].str.replace(r"(\[.*\])", "")

#delete trailing whitespace
hot100_radio_streaming_sales["original_lyrics"] = hot100_radio_streaming_sales["original_lyrics"].str.strip()
hot100_radio_streaming_sales["translated_lyrics"] = hot100_radio_streaming_sales["translated_lyrics"].str.strip()

#clean spacing: add space before linebreaks (so theyre counted separately)
hot100_radio_streaming_sales["translated_lyrics"] = hot100_radio_streaming_sales["translated_lyrics"].str.replace(r"(\n+)", " \n")
hot100_radio_streaming_sales["translated_lyrics"] = hot100_radio_streaming_sales["translated_lyrics"].str.replace(r"(\s+)", " ") #restandardize whitespace
hot100_radio_streaming_sales["translated_lyrics"] = hot100_radio_streaming_sales["translated_lyrics"].str.replace(r"(\s[, | \' | \? | \! | \. | \-]+)", " ")  #delete hanging punctuation
hot100_radio_streaming_sales["original_lyrics"] = hot100_radio_streaming_sales["original_lyrics"].str.replace(r"(\n+)", " \n")
hot100_radio_streaming_sales["original_lyrics"] = hot100_radio_streaming_sales["original_lyrics"].str.replace(r"(\s+)", " ") #restandardize whitespace
hot100_radio_streaming_sales["original_lyrics"] = hot100_radio_streaming_sales["original_lyrics"].str.replace(r"(\s[, | ' | \? | \! | \. | \-]+)", " ")  #delete hanging punctuation

#only roman characters and white space and punctuation
hot100_radio_streaming_sales["english_lyrics"] = hot100_radio_streaming_sales["original_lyrics"].str.replace(r"([^a-z | A-Z | \s | , | ' | \? | \! | \. | \- ])", " ")
hot100_radio_streaming_sales["english_lyrics"] = hot100_radio_streaming_sales["english_lyrics"].str.replace(r"(\s+)", " ") #restandardize whitespace
hot100_radio_streaming_sales["english_lyrics"] = hot100_radio_streaming_sales["english_lyrics"].str.replace(r"(\s[, | ' | \? | \! | \. | \-]+)", " ")  #delete hanging punctuation

##count number of english lyrics and total lyrics
hot100_radio_streaming_sales['english_count'] = [len(lyr.split(" ")) for lyr in hot100_radio_streaming_sales['english_lyrics']]
hot100_radio_streaming_sales['total_count'] = [len(lyr.split(" ")) for lyr in hot100_radio_streaming_sales['original_lyrics']]

##count number of unique english and total lyrics
hot100_radio_streaming_sales['english_unique'] = [len(set(lyr.split(" "))) for lyr in hot100_radio_streaming_sales['english_lyrics']]
hot100_radio_streaming_sales['total_unique'] = [len(set(lyr.split(" "))) for lyr in hot100_radio_streaming_sales['original_lyrics']]

### create columns for english percentage
hot100_radio_streaming_sales['english_percentage'] = hot100_radio_streaming_sales['english_count'] / hot100_radio_streaming_sales['total_count']
hot100_radio_streaming_sales['unique_english_percentage'] = hot100_radio_streaming_sales['english_unique'] / hot100_radio_streaming_sales['total_unique']

# %%
hot100_radio_streaming_sales
# Out:
#     chart_date              artist_x              song_title_x  \
# 0   2019-01-12              Pinkfong                Baby Shark
# 1   2009-10-31          Wonder Girls  Nobody (English release)
# 2   2012-09-22                   PSY             Gangnam Style
# 3   2013-04-27                   PSY                 Gentleman
# 4   2014-06-28  PSY feat. Snoop Dogg                  Hangover
# ..         ...                   ...                       ...
# 80         NaN                   NaN                       NaN
# 81         NaN                   NaN                       NaN
# 82         NaN                   NaN                       NaN
# 83         NaN                   NaN                       NaN
# 84         NaN                   NaN                       NaN
#
#                                          Original URL  \
# 0       https://genius.com/Pinkfong-baby-shark-lyrics
# 1   https://genius.com/Wonder-girls-nobody-english...
# 2         https://genius.com/Psy-gangnam-style-lyrics
# 3             https://genius.com/Psy-gentleman-lyrics
# 4              https://genius.com/Psy-hangover-lyrics
# ..                                                ...
# 80            https://genius.com/Bts-stay-gold-lyrics
# 81       https://genius.com/Bts-your-eyes-tell-lyrics
# 82         https://genius.com/K-da-the-baddest-lyrics
# 83       https://genius.com/Max-blueberry-eyes-lyrics
# 84            https://genius.com/Verivery-gbtb-lyrics
#
#                                       original_lyrics  \
# 0   Baby shark, doo doo doo doo doo doo Baby shark...
# 1   You know I still love you baby And it will nev...
# 2   Hangul 오빤 강남 스타일 강남 스타일 낮에는 따사로운 인간적인 여자 커피 한잔...
# 3   알랑가몰라 왜 화끈해야 하는건지 알랑가몰라 왜 말끔해야 하는건지 알랑가몰라 아리까리...
# 4   Hangover, hangover, hangover, hangover-over-ov...
# ..                                                ...
# 80  Ooh ooh In a world where you feel cold You got...
# 81  何故、こんなにも 涙が溢れるの ねえ、側にいて そして笑ってよ 君のいない未来は 色のない世...
# 82  Baddest do what the baddest do (Hey) The badde...
# 83  Mmm, mmm Da-da, ooh woah-oh, yeah MAX, baby Le...
# 84  Who’s gonna pull the trigger 운명을 가를 shot No mo...
#
#                               English Translation URL  \
# 0       https://genius.com/Pinkfong-baby-shark-lyrics
# 1   https://genius.com/Wonder-girls-nobody-english...
# 2   https://genius.com/Genius-english-translations...
# 3   https://lyricstranslate.com/en/gentleman-gentl...
# 4   https://colorcodedlyrics.com/2014/06/psy-ssai-...
# ..                                                ...
# 80  https://genius.com/Genius-english-translations...
# 81  https://genius.com/Genius-english-translations...
# 82  https://genius.com/Genius-english-translations...
# 83  https://genius.com/Genius-english-translations...
# 84      https://lyricstranslate.com/en/gbtb-gbtb.html
#
#                                     translated_lyrics  peak_position  \
# 0   Baby shark, doo doo doo doo doo doo Baby shark...           32.0
# 1   You know I still love you baby And it will nev...           76.0
# 2   Oppa Gangnam Style Gangnam style Warm human wo...            2.0
# 3   I don’t know if you know why it needs to be ho...            5.0
# 4   Hangover, hangover, hangover, hangover-over-ov...           26.0
# ..                                                ...            ...
# 80  Oh, woah, oh In a world where you feel cold Yo...            NaN
# 81  Why are my eyes filled with tears? Hey, stay b...            NaN
# 82  Baddest do what the baddest do (Hey) The badde...            NaN
# 83  Mmm, mmm Da-da, ooh woah-oh, yeah MAX, baby Le...            NaN
# 84  Who's gonna pull the trigger A shot aiming for...            NaN
#
#     chart_weeks                                     english_lyrics  ...  \
# 0          20.0  Baby shark, doo doo doo doo doo doo Baby shark...  ...
# 1           1.0  You know I still love you baby And it will nev...  ...
# 2           3.0  Hangul Hey Hey Hey Hey sexy lady sexy lady Hey...  ...
# 3           1.0   We like We-we-we like party Damn, girl You so...  ...
# 4           1.0  Hangover, hangover, hangover, hangover-over-ov...  ...
# ..          ...                                                ...  ...
# 80          NaN  Ooh ooh In a world where you feel cold You got...  ...
# 81          NaN   So beautiful follow me I ll find you So color...  ...
# 82          NaN  Baddest do what the baddest do Hey The baddest...  ...
# 83          NaN  Mmm, mmm Da-da, ooh woah-oh, yeah MAX, baby Le...  ...
# 84          NaN  Who s gonna pull the trigger shot No more barr...  ...
#
#     chart_weeks_streaming  chart_date_sales                  artist_y  \
# 0                6 (R) 59               NaN                       NaN
# 1                     NaN               NaN                       NaN
# 2                     122        2012-10-06                       PSY
# 3                      19        2013-05-04                       PSY
# 4                       1               NaN                       NaN
# ..                    ...               ...                       ...
# 80                    NaN        2020-07-04                       BTS
# 81                    NaN        2020-07-25                       BTS
# 82                    NaN        2020-09-12                      K/DA
# 83                    NaN        2020-09-26  Max Schneider feat. Suga
# 84                    NaN        2020-10-31                  Verivery
#
#       song_title_y  peak_position_sales  chart_weeks_sales english_unique  \
# 0              NaN                  NaN                NaN             24
# 1              NaN                  NaN                NaN            119
# 2    Gangnam Style                    1                 32             12
# 3        Gentleman                   20                  4             37
# 4              NaN                  NaN                NaN            170
# ..             ...                  ...                ...            ...
# 80       Stay Gold                    6                  1             41
# 81  Your Eyes Tell                   12                  1             16
# 82     The Baddest                   28                  1            180
# 83  Blueberry Eyes                   22                  1             87
# 84        G.B.T.B.                   44                  1             59
#
#    total_unique  english_percentage unique_english_percentage
# 0            23            1.032520                  1.043478
# 1           123            1.000000                  0.967480
# 2            83            0.114391                  0.144578
# 3            75            0.710660                  0.493333
# 4           211            0.948603                  0.805687
# ..          ...                 ...                       ...
# 80           91            0.718919                  0.450549
# 81           57            0.313433                  0.280702
# 82          220            0.903967                  0.818182
# 83          131            0.817427                  0.664122
# 84          163            0.697406                  0.361963
#
# [85 rows x 38 columns]

# %%
#write to csv
#radio.to_csv('subcharts - Radio_Kpop.csv')
#streaming.to_csv('subcharts - Streaming_Kpop.csv')
#sales.to_csv('subcharts - Sales_Kpop.csv')
hot100_radio_streaming_sales.to_csv('hot100_radio_streaming_sales_Kpop.csv')
