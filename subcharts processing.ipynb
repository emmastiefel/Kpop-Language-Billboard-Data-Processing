# %%
import pandas as pd
from datetime import timedelta
from datetime import datetime
import numpy as np
import matplotlib.pyplot as plt

import lyricsgenius
from fuzzywuzzy import fuzz

# %%
#function to convert strings to dates :)
def string_to_datetime(string):
    result = datetime.strptime(string, "%Y-%m-%d")       
    return result

# %%
#read in radio, streaming, sales data
radio = pd.read_csv('subcharts - Radio_Kpop.csv')
streaming = pd.read_csv('subcharts - Streaming_Kpop.csv')
sales = pd.read_csv('subcharts - Sales_Kpop.csv')
hot100 = pd.read_csv('BBSHRK - Spotify_BBH100_Kpop.csv')

# %%
##standardize artist and song names 
for chart in [sales, streaming, radio, hot100]:
    #drop random unnamed columns
    drop_columns = [c for c in chart.columns if 'Unnamed' in c ]
    chart.drop(columns=drop_columns, inplace=True)

    #remove wiki citations, standardize whitespace, remove quotation marks
    #regex patterns and replacement strings
    regex_pats = [[r"(\[\d+\])", ""], [r"(\s)", " "], [r"(\")", ""]]
    for pat in regex_pats:
        chart["artist"] = chart["artist"].str.replace(pat[0], pat[1])
        chart["song_title"] = chart["song_title"].str.replace(pat[0], pat[1])
        
    #separate out main artist: split by feat. and and
    chart['main_artist'] = chart['artist'].str.replace(r"(feat.*)", '')
    #handle suga/agust d specifically because this errror comes up a lot
    chart['main_artist'] = ['Agust D' if 'Agust D' in a else a for a in chart['main_artist']]
    chart['main_artist'] = chart['main_artist'].str.replace(r"(and.*)", '')
    chart['main_artist'] = chart['main_artist'].str.replace(r"(,.*)", '')
    chart['main_artist'] = chart['main_artist'].str.replace(r"(&.*)", '')
    chart['main_artist'] = chart['main_artist'].str.replace(r"(:.*)", '')

    #remove parentheticals from song name and artist name
    chart['search_title'] = chart['search_title'].str.replace(r"(\(.*\))", "")
    chart['main_artist'] = chart['main_artist'].str.replace(r"(\(.*\))", "")

    #strip out whitespace
    chart['search_title'] = chart['search_title'].str.strip()
    chart['main_artist'] = chart['main_artist'].str.strip()

    #convert chart_date to datetime object
    #chart["chart_date"] = [string_to_datetime(d) for d in chart["chart_date"]]

    #standardize peak positions (remove parentheticals) + remove trailing whitespace
    chart["peak_position"] = chart["peak_position"].str.replace(r"(\(.*)", "")
    chart["peak_position"] = chart["peak_position"].str.strip()

#sales.rename(columns={'chart_date':'chart_date_sales', 'peak_position':'peak_position_sales', 'chart_weeks':'chart_weeks_sales'}, inplace=True)
#streaming.rename(columns={'chart_date':'chart_date_streaming', 'peak_position':'peak_position_streaming', 'chart_weeks':'chart_weeks_streaming'}, inplace=True)
#radio.rename(columns={'chart_date':'chart_date_radio','peak_position':'peak_position_radio', 'chart_weeks':'chart_weeks_radio'}, inplace=True)

# %%
## merge other charts into the hot 100 data
hot100_radio = hot100.merge(radio, how='outer', on=['search_title', 'main_artist', 'artist'])
hot100_radio_streaming = hot100_radio.merge(streaming, how='outer', on=['search_title', 'main_artist', 'artist'])
hot100_radio_streaming_sales = hot100_radio_streaming.merge(sales, how='outer', on=['search_title', 'main_artist', 'artist'])

# %%
##fill in info for songs not on hot 100 (dont already have lyrics and other info identified)

#identify songs with missing info
hot100_radio_streaming_sales['missing_lyrics'] = pd.isna(hot100_radio_streaming_sales['original_lyrics'])
to_fill = hot100_radio_streaming_sales.loc[hot100_radio_streaming_sales['missing_lyrics'] == True]

# %%
### scrape lyrics from genius

genius = lyricsgenius.Genius('')

for artist_name in to_fill['main_artist'].unique():
    print(artist_name)
    #locate all songs the artist has in the top songs
    artist_songs = to_fill.loc[to_fill['main_artist'] == artist_name]

    try: #search for artist on genius, skip if not found
        #search for top songs for artist on genius, sorted by popularity -- should mostly match song chart positions
        artist_genius = genius.search_artist(artist_name, max_songs=1, sort="popularity")

        ##search for each song on genius and store lyrics
        for i, r in artist_songs.iterrows():
            print(r['search_title'])
            song_genius = artist_genius.song(r['search_title'])

            #store song lyrics if possible + exceeds similarity threshold, otherwise skip
            try:
                #partial ratio similarity, lowercase everything to avoid case mismatches
                similarity = fuzz.partial_ratio(r['search_title'].lower(), song_genius.title.lower())
                print(r['main_artist'], r['search_title'], " | ", song_genius.title, " | ", similarity)
        
                #if similarity is above threshold, store lyrics + url
                if similarity > 60:
                    lyrics_raw = song_genius.lyrics
                    print(lyrics_raw[:30])
                    hot100_radio_streaming_sales.at[i, 'original_lyrics'] = lyrics_raw
                    hot100_radio_streaming_sales.at[i, 'Original URL'] = song_genius.url
            except:
                print('song genius error')
    except:
        print('artist genius error')
# Out:
# K/DA
# Searching for songs by K/DA...
#
# Song 1: "POP/STARS"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Pop/Stars
# Searching for "Pop/Stars" by K/DA...
# Done.
# K/DA Pop/Stars  |  POP/STARS  |  100
# [Intro: Jaira Burns, Miyeon, M
# The Baddest
# Searching for "The Baddest" by K/DA...
# Done.
# K/DA The Baddest  |  THE BADDEST  |  100
# [Intro: Wolftyla]
# Baddest do w
# BTS
# Searching for songs by BTS...
#
# Changing artist name to 'BTS (방탄소년단)'
# Song 1: "Dynamite"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# 2! 3!
# Searching for "2! 3!" by BTS (방탄소년단)...
# Done.
# BTS 2! 3!  |  둘! 셋! (그래도 좋은 날이 더 많기를) [2! 3! (Still Wishing For More Good Days)]  |  100
# 방탄소년단의 둘! 셋! (그래도 좋은 날이 더 많기를)
# Make It Right
# Searching for "Make It Right" by BTS (방탄소년단)...
# Done.
# BTS Make It Right  |  Make It Right  |  100
# [Verse 1: V]
# 내가 날 눈치챘던 순간
# 떠나야만
# Make It Right remix
# Searching for "Make It Right remix" by BTS (방탄소년단)...
# Done.
# BTS Make It Right remix  |  Make It Right (Remix)  |  95
# [Verse 1: Lauv]
# Yeah, I was lo
# Mikrokosmos
# Searching for "Mikrokosmos" by BTS (방탄소년단)...
# Done.
# BTS Mikrokosmos  |  소우주 (Mikrokosmos)  |  100
# [Verse 1: Jungkook, V]
# 반짝이는 별빛
# Home
# Searching for "Home" by BTS (방탄소년단)...
# Done.
# BTS Home  |  HOME  |  100
# [방탄소년단의 "HOME" 가사]
#
# [Intro: RM
# Dionysus
# Searching for "Dionysus" by BTS (방탄소년단)...
# Done.
# BTS Dionysus  |  Dionysus  |  100
# [Intro: J-Hope, V]
# 쭉 들이켜, 술잔 (
# Jamais Vu
# Searching for "Jamais Vu" by BTS (방탄소년단)...
# Done.
# BTS Jamais Vu  |  Jamais Vu  |  100
# [Verse 1: Jin]
# 또 져버린 것 같아
# 넌 화가
# Intro: Persona
# Searching for "Intro: Persona" by BTS (방탄소년단)...
# Done.
# BTS Intro: Persona  |  Intro: Persona  |  100
# [Intro: Persona - RM 가사]
#
# [Ver
# Dream Glow
# Searching for "Dream Glow" by BTS (방탄소년단)...
# No results found for: 'Dream Glow BTS (방탄소년단)'
# song genius error
# A Brand New Day
# Searching for "A Brand New Day" by BTS (방탄소년단)...
# No results found for: 'A Brand New Day BTS (방탄소년단)'
# song genius error
# All Night
# Searching for "All Night" by BTS (방탄소년단)...
# Done.
# BTS All Night  |  Glory  |  25
# Heartbeat
# Searching for "Heartbeat" by BTS (방탄소년단)...
# Done.
# BTS Heartbeat  |  Heartbeat  |  100
# [Intro: V & Jungkook]
# It leave
# Lights
# Searching for "Lights" by BTS (방탄소년단)...
# Done.
# BTS Lights  |  Lights  |  100
# [防彈少年團 Lights 歌詞]
#
# [Verse 1: J
# Friends
# Searching for "Friends" by BTS (방탄소년단)...
# Done.
# BTS Friends  |  친구 (Friends)  |  100
# [방탄소년단 - 친구 (Friends) 가사]
#
# [Ve
# Louder Than Bombs
# Searching for "Louder Than Bombs" by BTS (방탄소년단)...
# Done.
# BTS Louder Than Bombs  |  Louder than bombs  |  100
# [방탄소년단 - Louder than bombs 가사]
# Inner Child
# Searching for "Inner Child" by BTS (방탄소년단)...
# Done.
# BTS Inner Child  |  Inner Child  |  100
# [방탄소년단 - Inner Child 가사]
#
# [Ver
# We Are Bulletproof: The Eternal
# Searching for "We Are Bulletproof: The Eternal" by BTS (방탄소년단)...
# Done.
# BTS We Are Bulletproof: The Eternal  |  We Are Bulletproof : The Eternal  |  97
# [방탄소년단 We Are Bulletproof: The
# Ugh!
# Searching for "Ugh!" by BTS (방탄소년단)...
# Done.
# BTS Ugh!  |  욱 (UGH!)  |  100
# [방탄소년단 - 욱 (UGH!) 가사]
#
# [Intro]
# 00:00
# Searching for "00:00" by BTS (방탄소년단)...
# Done.
# BTS 00:00  |  00:00 (Zero O’Clock)  |  100
# [방탄소년단 - 00:00 (Zero O'Clock)
# Moon
# Searching for "Moon" by BTS (방탄소년단)...
# Done.
# BTS Moon  |  Moon  |  100
# [방탄소년단 - Moon 가사]
#
# [Verse 1: J
# Interlude: Shadow
# Searching for "Interlude: Shadow" by BTS (방탄소년단)...
# Done.
# BTS Interlude: Shadow  |  Interlude: Shadow  |  100
# [방탄소년단 - Interlude: Shadow 가사]
# Outro: Ego
# Searching for "Outro: Ego" by BTS (방탄소년단)...
# Done.
# BTS Outro: Ego  |  Outro: Ego  |  100
# [방탄소년단 Outro: Ego 가사]
#
# [Intro:
# Respect
# Searching for "Respect" by BTS (방탄소년단)...
# Done.
# BTS Respect  |  Respect  |  100
# [방탄소년단 - Respect 가사]
#
# [Intro:
# Stay Gold
# Searching for "Stay Gold" by BTS (방탄소년단)...
# Done.
# BTS Stay Gold  |  Stay Gold  |  100
# [Intro: Jungkook, SUGA]
# Ooh oo
# Your Eyes Tell
# Searching for "Your Eyes Tell" by BTS (방탄소년단)...
# Done.
# BTS Your Eyes Tell  |  Your eyes tell  |  100
# [防弾少年団（ビーティーエス）「Your eyes tell
# Halsey
# Searching for songs by Halsey...
#
# Song 1: "Without Me"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Suga's Interlude
# Searching for "Suga's Interlude" by Halsey...
# Done.
# Halsey Suga's Interlude  |  SUGA’s Interlude  |  94
# [Intro: Halsey]
# I've been tryi
# Younha
# Searching for songs by Younha...
#
# Changing artist name to 'YOUNHA (윤하)'
# Song 1: "Winter Flower (雪中梅)"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Winter Flower
# Searching for "Winter Flower" by YOUNHA (윤하)...
# Done.
# Younha Winter Flower  |  Winter Flower (雪中梅)  |  100
# [윤하 "Winter Flower (雪中梅) Ft. R
# Lauv
# Searching for songs by Lauv...
#
# Song 1: "I Like Me Better"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Who
# Searching for "Who" by Lauv...
# Done.
# Lauv Who  |  Who  |  100
# [Verse 1: Lauv]
# Outlines of yo
# V
# Searching for songs by V...
#
# Changing artist name to 'Kanye West'
# Song 1: "Mercy"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Sweet Night
# Searching for "Sweet Night" by Kanye West...
# Done.
# V Sweet Night  |  2017 OMO-FERINA Single Listening Log  |  45
# IU
# Searching for songs by IU...
#
# Changing artist name to 'IU (아이유)'
# Song 1: "에잇 (eight)"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Eight
# Searching for "Eight" by IU (아이유)...
# Done.
# IU Eight  |  에잇 (eight)  |  100
# [Verse 1: IU]
# So are you happy
# Agust D
# Searching for songs by Agust D...
#
# Song 1: "Agust D"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Strange
# Searching for "Strange" by Agust D...
# Done.
# Agust D Strange  |  이상하지 않은가 (Strange)  |  100
# [이상하지 않은가 (Strange) 가사]
#
# [Intr
# Burn It
# Searching for "Burn It" by Agust D...
# Done.
# Agust D Burn It  |  Burn It  |  100
# [Burn It 가사]
#
# [Chorus: MAX]
# I
# What Do You Think?
# Searching for "What Do You Think?" by Agust D...
# Done.
# Agust D What Do You Think?  |  어떻게 생각해? (What do you think?)  |  100
# [어떻게 생각해? (What do you think?)
# Moonlight
# Searching for "Moonlight" by Agust D...
# Done.
# Agust D Moonlight  |  저 달 (Moonlight)  |  100
# [저 달 (Moonlight) 가사]
#
# [Intro]
#
# People
# Searching for "People" by Agust D...
# Done.
# Agust D People  |  사람 (People)  |  100
# [사람 (People) 가사]
#
# [Verse 1]
# Ye
# 28
# Searching for "28" by Agust D...
# Done.
# Agust D 28  |  점점 어른이 되나봐 (28)  |  100
# [점점 어른이 되나봐 (28) 가사]
#
# [Verse 1
# Dear My Friend
# Searching for "Dear My Friend" by Agust D...
# Done.
# Agust D Dear My Friend  |  어땠을까 (Dear my friend)  |  100
# [어땠을까 (Dear my friend) 가사]
#
# [C
# Interlude: Set Me Free
# Searching for "Interlude: Set Me Free" by Agust D...
# Done.
# Agust D Interlude: Set Me Free  |  Interlude: Set me free  |  100
# [Interlude: Set me free 가사]
#
# [
# Honsool
# Searching for "Honsool" by Agust D...
# Done.
# Agust D Honsool  |  혼술 (Honsool)  |  100
# [혼술 (Honsool) 가사]
#
# [Verse 1]
# 오
# Max Schneider
# Searching for songs by Max Schneider...
#
# Changing artist name to 'MAX'
# Song 1: "Lights Down Low"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Blueberry Eyes
# Searching for "Blueberry Eyes" by MAX...
# Done.
# Max Schneider Blueberry Eyes  |  Blueberry Eyes  |  100
# [Intro: MAX]
# Mmm, mmm
# Da-da, o
# Verivery
# Searching for songs by Verivery...
#
# Changing artist name to 'VERIVERY'
# Song 1: "Lay Back"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# G.B.T.B.
# Searching for "G.B.T.B." by VERIVERY...
# Done.
# Verivery G.B.T.B.  |  G.B.T.B.  |  100
# [VERIVERY "G.B.T.B." 가사]
#
# Who’

# %%
### scrape translated lyrics from genius

## access artist object for all genius songs translated into english
translations = genius.search_artist('Genius English Translations', sort='popularity', max_songs=1)

## search for each song on the english translations page
for i, r in to_fill.iterrows():
    title = r['search_title']
    artist = r['main_artist']
    #only run for songs that don't have translated lyrics stored (for re-runs)
    print(title)
    song_trans = translations.song(artist + ' - ' + title)

    #only run if results turn something up and song object isn't empty
    if song_trans:
        #partial ratio similarity, lowercase everything to avoid case mismatches
        similarity = fuzz.partial_ratio((artist + ' - ' + title).lower(), song_trans.title.lower())
        print(artist, title, " | ", song_trans.title, " | ", similarity)

        #if similarity is above threshold, store translated lyrics
        if similarity > 60:
            hot100_radio_streaming_sales.at[i, 'translated_lyrics'] = song_trans.lyrics
            hot100_radio_streaming_sales.at[i, 'English Translation URL'] = song_trans.url
# Out:
# Searching for songs by Genius English Translations...
#
# Song 1: "Luis Fonsi & Daddy Yankee - Despacito (Remix) ft. Justin Bieber (English Translation)"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Pop/Stars
# Searching for "K/DA - Pop/Stars" by Genius English Translations...
# Done.
# K/DA Pop/Stars  |  K/DA - POP/STARS (English Translation)  |  100
# 2! 3!
# Searching for "BTS - 2! 3!" by Genius English Translations...
# Done.
# BTS 2! 3!  |  BTS - 둘! 셋! (그래도 좋은 날이 더 많기를) [2! 3! (Still Wishing For More Good Days)] (English Translation)  |  82
# Make It Right
# Searching for "BTS - Make It Right" by Genius English Translations...
# Done.
# BTS Make It Right  |  BTS - Make It Right (English Translation)  |  100
# Make It Right remix
# Searching for "BTS - Make It Right remix" by Genius English Translations...
# Done.
# BTS Make It Right remix  |  BTS - Make It Right (Remix) ft. Lauv (English Translation)  |  96
# Mikrokosmos
# Searching for "BTS - Mikrokosmos" by Genius English Translations...
# Done.
# BTS Mikrokosmos  |  BTS - 소우주 (Mikrokosmos) (English Translation)  |  76
# Home
# Searching for "BTS - Home" by Genius English Translations...
# Done.
# BTS Home  |  BTS - HOME (English Translation)  |  100
# Dionysus
# Searching for "BTS - Dionysus" by Genius English Translations...
# Done.
# BTS Dionysus  |  BTS - Dionysus (English Translation)  |  100
# Jamais Vu
# Searching for "BTS - Jamais Vu" by Genius English Translations...
# Done.
# BTS Jamais Vu  |  BTS - Jamais Vu (English Translation)  |  100
# Intro: Persona
# Searching for "BTS - Intro: Persona" by Genius English Translations...
# Done.
# BTS Intro: Persona  |  BTS - Intro: Persona (English Translation)  |  100
# Dream Glow
# Searching for "BTS - Dream Glow" by Genius English Translations...
# Done.
# BTS Dream Glow  |  BTS & Charli XCX - Dream Glow (English Translation)  |  81
# A Brand New Day
# Searching for "BTS - A Brand New Day" by Genius English Translations...
# Done.
# BTS A Brand New Day  |  BTS & Zara Larsson - A Brand New Day (English Translation)  |  90
# All Night
# Searching for "BTS - All Night" by Genius English Translations...
# Done.
# BTS All Night  |  BTS & Juice WRLD - All Night (English Translation)  |  80
# Heartbeat
# Searching for "BTS - Heartbeat" by Genius English Translations...
# Done.
# BTS Heartbeat  |  BTS - Heartbeat (English Translation)  |  100
# Lights
# Searching for "BTS - Lights" by Genius English Translations...
# Done.
# BTS Lights  |  BTS - Lights (English Translation)  |  100
# Suga's Interlude
# Searching for "Halsey - Suga's Interlude" by Genius English Translations...
# Done.
# Halsey Suga's Interlude  |  Halsey, SUGA & BTS - SUGA’s Interlude (English Translation)  |  76
# Winter Flower
# Searching for "Younha - Winter Flower" by Genius English Translations...
# Done.
# Younha Winter Flower  |  YOUNHA - Winter Flower (雪中梅) ft. RM (English Translation)  |  100
# Friends
# Searching for "BTS - Friends" by Genius English Translations...
# Done.
# BTS Friends  |  BTS - 친구 (Friends) (English Translation)  |  69
# Louder Than Bombs
# Searching for "BTS - Louder Than Bombs" by Genius English Translations...
# Done.
# BTS Louder Than Bombs  |  BTS - Louder than bombs (English Translation)  |  100
# Inner Child
# Searching for "BTS - Inner Child" by Genius English Translations...
# Done.
# BTS Inner Child  |  BTS - Inner Child (English Translation)  |  100
# We Are Bulletproof: The Eternal
# Searching for "BTS - We Are Bulletproof: The Eternal" by Genius English Translations...
# Done.
# BTS We Are Bulletproof: The Eternal  |  BTS - We Are Bulletproof: The Eternal (English Translation)  |  100
# Ugh!
# Searching for "BTS - Ugh!" by Genius English Translations...
# Done.
# BTS Ugh!  |  BTS - 욱 (UGH!) (English Translation)  |  70
# 00:00
# Searching for "BTS - 00:00" by Genius English Translations...
# Done.
# BTS 00:00  |  BTS - 00:00 (Zero O’Clock) (English Translation)  |  100
# Moon
# Searching for "BTS - Moon" by Genius English Translations...
# Done.
# BTS Moon  |  BTS - Moon (English Translation)  |  100
# Interlude: Shadow
# Searching for "BTS - Interlude: Shadow" by Genius English Translations...
# Done.
# BTS Interlude: Shadow  |  BTS - Interlude: Shadow (English Translation)  |  100
# Outro: Ego
# Searching for "BTS - Outro: Ego" by Genius English Translations...
# Done.
# BTS Outro: Ego  |  BTS - Outro: Ego (English Translation)  |  100
# Respect
# Searching for "BTS - Respect" by Genius English Translations...
# Done.
# BTS Respect  |  BTS - Respect (English Translation)  |  100
# Who
# Searching for "Lauv - Who" by Genius English Translations...
# Done.
# Lauv Who  |  Henry Lau - 当你孤单你会想起谁 (Who Will You Think Of?)  |  60
# Sweet Night
# Searching for "V - Sweet Night" by Genius English Translations...
# Done.
# V Sweet Night  |  The Vampire, His Kith And Kin - Chapter 5  |  36
# Eight
# Searching for "IU - Eight" by Genius English Translations...
# Done.
# IU Eight  |  IU - 에잇 (eight) ft. SUGA (English Translation)  |  70
# Strange
# Searching for "Agust D - Strange" by Genius English Translations...
# Done.
# Agust D Strange  |  Agust D - 이상하지않은가 (Strange) ft. RM (English Translation)  |  59
# Burn It
# Searching for "Agust D - Burn It" by Genius English Translations...
# Done.
# Agust D Burn It  |  Agust D - Burn It ft. MAX (English Translation)  |  100
# What Do You Think?
# Searching for "Agust D - What Do You Think?" by Genius English Translations...
# Done.
# Agust D What Do You Think?  |  Agust D - 어떻게 생각해? (What do you think?) (English Translation)  |  71
# Moonlight
# Searching for "Agust D - Moonlight" by Genius English Translations...
# Done.
# Agust D Moonlight  |  Agust D - 저 달 (Moonlight) (English Translation)  |  74
# People
# Searching for "Agust D - People" by Genius English Translations...
# Done.
# Agust D People  |  Agust D - 사람 (People) (English Translation)  |  75
# 28
# Searching for "Agust D - 28" by Genius English Translations...
# Done.
# Agust D 28  |  Agust D - 점점 어른이 되나봐 (28) ft. NiiHWA (English Translation)  |  83
# Dear My Friend
# Searching for "Agust D - Dear My Friend" by Genius English Translations...
# Done.
# Agust D Dear My Friend  |  Agust D - 어땠을까 (Dear my friend) ft. Kim Jong Wan (English Translation)  |  75
# Interlude: Set Me Free
# Searching for "Agust D - Interlude: Set Me Free" by Genius English Translations...
# Done.
# Agust D Interlude: Set Me Free  |  Agust D - Interlude: Set me free (English Translation)  |  100
# Honsool
# Searching for "Agust D - Honsool" by Genius English Translations...
# Done.
# Agust D Honsool  |  Agust D - 혼술 (Honsool) (English Translation)  |  76
# Stay Gold
# Searching for "BTS - Stay Gold" by Genius English Translations...
# Done.
# BTS Stay Gold  |  BTS - Stay Gold (English Translation)  |  100
# Your Eyes Tell
# Searching for "BTS - Your Eyes Tell" by Genius English Translations...
# Done.
# BTS Your Eyes Tell  |  BTS - Your eyes tell (English Translation)  |  100
# The Baddest
# Searching for "K/DA - The Baddest" by Genius English Translations...
# Done.
# K/DA The Baddest  |  K/DA - THE BADDEST (English Translation)  |  100
# Blueberry Eyes
# Searching for "Max Schneider - Blueberry Eyes" by Genius English Translations...
# No results found for: 'Max Schneider - Blueberry Eyes Genius English Translations'
# G.B.T.B.
# Searching for "Verivery - G.B.T.B." by Genius English Translations...
# No results found for: 'Verivery - G.B.T.B. Genius English Translations'

# %%
### scrape musical element data from spotify
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import time

##setup spotify api interface
client_id = ''
client_secret = ''

client_credentials_manager = SpotifyClientCredentials(client_id, client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

#new column forr spotify id
hot100_radio_streaming_sales['spotify_id'] = ['' for s in hot100_radio_streaming_sales['artist']]

#rerun for all songs because I want to store spotify ids now
for i, r in hot100_radio_streaming_sales.iterrows():
    song = r['search_title']
    artist = r['main_artist']
    print(song, artist)

    #search spotify
    spotify_search = sp.search('track:'+song+' artist:'+artist+'', type='track')
    time.sleep(6)

    #if it successfully finds a song, print out validation info
    if len(spotify_search['tracks']['items']) > 0:
        #print song id for test query - just take top return
        this_id = spotify_search['tracks']['items'][0]['id']
        this_name = spotify_search['tracks']['items'][0]['name']
        this_artist = spotify_search['tracks']['items'][0]['album']['artists'][0]['name']
        print(this_name, this_artist)

        this_features = sp.audio_features(this_id)[0]

        hot100_radio_streaming_sales.at[i, 'valence'] = this_features['valence']
        hot100_radio_streaming_sales.at[i, 'danceability'] = this_features['danceability']
        hot100_radio_streaming_sales.at[i, 'spotify_id'] = this_id

    else:
        print('No results :(')
        hot100_radio_streaming_sales.at[i, 'valence'] = np.nan
        hot100_radio_streaming_sales.at[i, 'danceability'] = np.nan

    print('___________')
# Out:
# Baby Shark Pinkfong
# Baby Shark Pinkfong
# ___________
# Nobody Wonder Girls
# Nobody Wonder Girls
# ___________
# Gangnam Style Psy
# Gangnam Style (강남스타일) PSY
# ___________
# Gentleman Psy
# Gentleman Various Artists
# ___________
# Hangover Psy
# Hangover PSY
# ___________
# Daddy Psy
# DADDY PSY
# ___________
# Lifted CL
# You're Love Lifted Me Clarence Carter
# ___________
# DNA BTS
# DNA BTS
# ___________
# MIC Drop BTS
# MIC Drop (Steve Aoki Remix) [Full Length Edition] BTS
# ___________
# Fake Love BTS
# FAKE LOVE BTS
# ___________
# Ddu-Du Ddu-Du Blackpink
# DDU-DU DDU-DU BLACKPINK
# ___________
# Idol BTS
# IDOL BTS
# ___________
# Kiss and Make Up Dua Lipa
# Kiss and Make Up Dua Lipa
# ___________
# Waste It on Me Steve Aoki
# Waste It On Me Steve Aoki
# ___________
# Kill This Love Blackpink
# Kill This Love BLACKPINK
# ___________
# Boy with Luv BTS
# Boy With Luv (feat. Halsey) BTS
# ___________
# Make It Right  Make It Right remix BTS
# Make It Right (feat. Lauv) [Acoustic Remix] BTS
# ___________
# Chicken Noodle Soup J-Hope
# Chicken Noodle Soup (feat. Becky G) j-hope
# ___________
# Black Swan BTS
# Black Swan BTS
# ___________
# On BTS
# Life Goes On BTS
# ___________
# My Time BTS
# My Time BTS
# ___________
# Filter BTS
# Filter BTS
# ___________
# Daechwita Agust D
# Daechwita Agust D
# ___________
# Sour Candy Lady Gaga
# Sour Candy (with BLACKPINK) Lady Gaga
# ___________
# Savage Love Jawsh 685
# Savage Love (Laxed - Siren Beat) Jawsh 685
# ___________
# How You Like That Blackpink
# How You Like That BLACKPINK
# ___________
# Dynamite BTS
# Dynamite BTS
# ___________
# Ice Cream Blackpink
# Ice Cream (with Selena Gomez) BLACKPINK
# ___________
# Lovesick Girls Blackpink
# Lovesick Girls BLACKPINK
# ___________
# Life Goes On BTS
# Life Goes On BTS
# ___________
# Blue & Grey BTS
# Blue & Grey BTS
# ___________
# Stay BTS
# Stay BTS
# ___________
# Fly to My Room BTS
# Fly To My Room BTS
# ___________
# Telepathy BTS
# Telepathy BTS
# ___________
# Dis-ease BTS
# Dis-ease BTS
# ___________
# Pop/Stars K/DA
# POP/STARS K/DA
# ___________
# 2! 3! BTS
# 2! 3! BTS
# ___________
# Make It Right BTS
# Make It Right (feat. Lauv) BTS
# ___________
# Make It Right remix BTS
# Make It Right (feat. Lauv) [Acoustic Remix] BTS
# ___________
# Mikrokosmos BTS
# Mikrokosmos BTS
# ___________
# Home BTS
# HOME BTS
# ___________
# Dionysus BTS
# Dionysus BTS
# ___________
# Jamais Vu BTS
# Jamais Vu BTS
# ___________
# Intro: Persona BTS
# Intro : Persona BTS
# ___________
# Dream Glow BTS
# Dream Glow (BTS World Original Soundtrack) - Pt. 1 BTS
# ___________
# A Brand New Day BTS
# A Brand New Day (BTS World Original Soundtrack) [Pt. 2] BTS
# ___________
# All Night BTS
# All Night (BTS World Original Soundtrack) [Pt. 3] BTS
# ___________
# Heartbeat BTS
# Heartbeat (BTS World Original Soundtrack) Various Artists
# ___________
# Lights BTS
# Lights BTS
# ___________
# Suga's Interlude Halsey
# SUGA's Interlude Halsey
# ___________
# Winter Flower Younha
# WINTER FLOWER(Feat.RM) Younha
# ___________
# Friends BTS
# Friends BTS
# ___________
# Louder Than Bombs BTS
# Louder than bombs BTS
# ___________
# Inner Child BTS
# Inner Child BTS
# ___________
# We Are Bulletproof: The Eternal BTS
# We are Bulletproof : the Eternal BTS
# ___________
# Ugh! BTS
# UGH! BTS
# ___________
# 00:00 BTS
# 00:00 (Zero O’Clock) BTS
# ___________
# Moon BTS
# Moon BTS
# ___________
# Interlude: Shadow BTS
# Interlude : Shadow BTS
# ___________
# Outro: Ego BTS
# Outro : Ego BTS
# ___________
# Respect BTS
# Respect BTS
# ___________
# Who Lauv
# Who (feat. BTS) Lauv
# ___________
# Sweet Night V
# Sweet Night V
# ___________
# Eight IU
# eight(Prod.&Feat. SUGA of BTS) IU
# ___________
# Strange Agust D
# Strange Agust D
# ___________
# Burn It Agust D
# Burn It Agust D
# ___________
# What Do You Think? Agust D
# What do you think? Agust D
# ___________
# Moonlight Agust D
# Moonlight Agust D
# ___________
# People Agust D
# People Agust D
# ___________
# 28 Agust D
# 28 Agust D
# ___________
# Dear My Friend Agust D
# Dear my friend (feat. Kim Jong Wan of NELL) Agust D
# ___________
# Interlude: Set Me Free Agust D
# Interlude : Set me free Agust D
# ___________
# Honsool Agust D
# Honsool Agust D
# ___________
# Stay Gold BTS
# Stay Gold BTS
# ___________
# Your Eyes Tell BTS
# Your eyes tell BTS
# ___________
# The Baddest K/DA
# THE BADDEST K/DA
# ___________
# Blueberry Eyes Max Schneider
# Blueberry Eyes (feat. SUGA of BTS) MAX
# ___________
# G.B.T.B. Verivery
# G.B.T.B. VERIVERY
# ___________

# %%
#there are a few unsuccessful searches and mismatches i will correct manually

#### spotify mistakes
##mismatched on by bts and life goes on by bts
on_features = sp.audio_features('2QyuXBcV1LJ2rq01KhreMF')[0]
on_index = hot100_radio_streaming_sales.loc[hot100_radio_streaming_sales['search_title'] == 'On'].index[0]
hot100_radio_streaming_sales.at[on_index, 'valence'] = on_features['valence']
hot100_radio_streaming_sales.at[on_index, 'danceability'] = on_features['danceability']
hot100_radio_streaming_sales.at[on_index, 'spotify_id'] = '2QyuXBcV1LJ2rq01KhreMF'

##mismatched lifted by cl and You're Love Lifted Me Clarence Carter
lifted_features = sp.audio_features('2DHWM8Bm4zuzuH7UOXscJw')[0]
lifted_index = hot100_radio_streaming_sales.loc[hot100_radio_streaming_sales['search_title'] == 'Lifted'].index[0]
hot100_radio_streaming_sales.at[lifted_index, 'valence'] = lifted_features['valence']
hot100_radio_streaming_sales.at[lifted_index, 'danceability'] = lifted_features['danceability']
hot100_radio_streaming_sales.at[lifted_index, 'spotify_id'] = '2DHWM8Bm4zuzuH7UOXscJw'

# %%
#### original lyrics mistakes

## missed sweet night by v
sn_genius = genius.search_song("Sweet Night", "V")
sn_index = hot100_radio_streaming_sales.loc[hot100_radio_streaming_sales['search_title'] == 'Sweet Night'].index[0]
hot100_radio_streaming_sales.at[sn_index, 'Original URL'] = sn_genius.url
hot100_radio_streaming_sales.at[sn_index, 'original_lyrics'] = sn_genius.lyrics
# Out:
# Searching for "Sweet Night" by V...
# Done.

# %%
## missed Dream Glow by BTS and Charli XCX
dg_genius = genius.search_song("Dream Glow", "BTS and Charli XCX")
dg_index = hot100_radio_streaming_sales.loc[hot100_radio_streaming_sales['search_title'] == 'Dream Glow'].index[0]
hot100_radio_streaming_sales.at[dg_index, 'Original URL'] = dg_genius.url
hot100_radio_streaming_sales.at[dg_index, 'original_lyrics'] = dg_genius.lyrics
# Out:
# Searching for "Dream Glow" by BTS and Charli XCX...
# Done.

# %%
## missed A Brand New Day by BTS and Zara Larsson	
bnd_genius = genius.search_song("A Brand New Day", "BTS and Zara Larsson")
bnd_index = hot100_radio_streaming_sales.loc[hot100_radio_streaming_sales['search_title'] == 'A Brand New Day'].index[0]
hot100_radio_streaming_sales.at[bnd_index, 'Original URL'] = bnd_genius.url
hot100_radio_streaming_sales.at[bnd_index, 'original_lyrics'] = bnd_genius.lyrics
# Out:
# Searching for "A Brand New Day" by BTS and Zara Larsson...
# Done.

# %%
## missed All Night by BTS and Juice Wrld	
an_genius = genius.search_song("All Night", "BTS and Juice Wrld")
an_index = hot100_radio_streaming_sales.loc[hot100_radio_streaming_sales['search_title'] == 'All Night'].index[0]
hot100_radio_streaming_sales.at[an_index, 'Original URL'] = an_genius.url
hot100_radio_streaming_sales.at[an_index, 'original_lyrics'] = an_genius.lyrics
# Out:
# Searching for "All Night" by BTS and Juice Wrld...
# Done.

# %%
#### translated lyrics mistakes

## sweet night is entirely in english
sn_index = hot100_radio_streaming_sales.loc[hot100_radio_streaming_sales['search_title'] == 'Sweet Night'].index[0]
hot100_radio_streaming_sales.at[sn_index, 'English Translation URL'] = hot100_radio_streaming_sales.at[sn_index, 'Original URL']
hot100_radio_streaming_sales.at[sn_index, 'translated_lyrics'] = hot100_radio_streaming_sales.at[sn_index, 'original_lyrics']

## who is also entirely in english
who_index = hot100_radio_streaming_sales.loc[hot100_radio_streaming_sales['search_title'] == 'Who'].index[0]
hot100_radio_streaming_sales.at[who_index, 'English Translation URL'] = hot100_radio_streaming_sales.at[who_index, 'Original URL']
hot100_radio_streaming_sales.at[who_index, 'translated_lyrics'] = hot100_radio_streaming_sales.at[who_index, 'original_lyrics']

# %%
## missed translation for strange
strange_genius = genius.search_song("Agust D - 이상하지않은가 (Strange) ft. RM (English Translation)", "Genius English Translations")
strange_index = hot100_radio_streaming_sales.loc[hot100_radio_streaming_sales['search_title'] == 'Strange'].index[0]
hot100_radio_streaming_sales.at[strange_index, 'English Translation URL'] = strange_genius.url
hot100_radio_streaming_sales.at[strange_index, 'translated_lyrics'] = strange_genius.lyrics
# Out:
# Searching for "Agust D - 이상하지않은가 (Strange) ft. RM (English Translation)" by Genius English Translations...
# Done.

# %%
## missed translation for blueberry eyes
bbe_genius = genius.search_song("MAX - Blueberry Eyes ft. SUGA (English Translation)", "Genius English Translations")
bbe_index = hot100_radio_streaming_sales.loc[hot100_radio_streaming_sales['search_title'] == 'Blueberry Eyes'].index[0]
hot100_radio_streaming_sales.at[bbe_index, 'English Translation URL'] = bbe_genius.url
hot100_radio_streaming_sales.at[bbe_index, 'translated_lyrics'] = bbe_genius.lyrics
# Out:
# Searching for "MAX - Blueberry Eyes ft. SUGA (English Translation)" by Genius English Translations...
# Done.

# %%
## genius does not have english translaltion of gbtb
gbtb_index = hot100_radio_streaming_sales.loc[hot100_radio_streaming_sales['search_title'] == 'G.B.T.B.'].index[0]
hot100_radio_streaming_sales.at[gbtb_index, 'English Translation URL'] = 'https://lyricstranslate.com/en/gbtb-gbtb.html'
hot100_radio_streaming_sales.at[gbtb_index, 'translated_lyrics'] = open("Manual Lyrics/GBTB.txt", "r").read()

# %%
#### re-process data now that it is all collected

#scale spotify valence values
hot100_radio_streaming_sales['scaled_valence'] = [s*2 - 1 for s in hot100_radio_streaming_sales['valence']]

##process text 
#remove romanized lyrics that are in some genius pages
hot100_radio_streaming_sales["original_lyrics"] = [lyrics.split("Romanization")[0] for lyrics in hot100_radio_streaming_sales["original_lyrics"]]

#get rid of bracketed sections like verse indicators
hot100_radio_streaming_sales["original_lyrics"] = hot100_radio_streaming_sales["original_lyrics"].str.replace(r"(\[.*\])", "")
hot100_radio_streaming_sales["translated_lyrics"] = hot100_radio_streaming_sales["translated_lyrics"].str.replace(r"(\[.*\])", "")

#delete trailing whitespace
hot100_radio_streaming_sales["original_lyrics"] = hot100_radio_streaming_sales["original_lyrics"].str.strip()
hot100_radio_streaming_sales["translated_lyrics"] = hot100_radio_streaming_sales["translated_lyrics"].str.strip()

#clean spacing: add space before linebreaks (so theyre counted separately)
hot100_radio_streaming_sales["translated_lyrics"] = hot100_radio_streaming_sales["translated_lyrics"].str.replace(r"(\n+)", " \n")
hot100_radio_streaming_sales["translated_lyrics"] = hot100_radio_streaming_sales["translated_lyrics"].str.replace(r"(\s+)", " ") #restandardize whitespace
hot100_radio_streaming_sales["translated_lyrics"] = hot100_radio_streaming_sales["translated_lyrics"].str.replace(r"(\s[, | \' | \? | \! | \. | \-]+)", " ")  #delete hanging punctuation
hot100_radio_streaming_sales["original_lyrics"] = hot100_radio_streaming_sales["original_lyrics"].str.replace(r"(\n+)", " \n")
hot100_radio_streaming_sales["original_lyrics"] = hot100_radio_streaming_sales["original_lyrics"].str.replace(r"(\s+)", " ") #restandardize whitespace
hot100_radio_streaming_sales["original_lyrics"] = hot100_radio_streaming_sales["original_lyrics"].str.replace(r"(\s[, | ' | \? | \! | \. | \-]+)", " ")  #delete hanging punctuation

#only roman characters and white space and punctuation
hot100_radio_streaming_sales["english_lyrics"] = hot100_radio_streaming_sales["original_lyrics"].str.replace(r"([^a-z | A-Z | \s | , | ' | \? | \! | \. | \- ])", " ")
hot100_radio_streaming_sales["english_lyrics"] = hot100_radio_streaming_sales["english_lyrics"].str.replace(r"(\s+)", " ") #restandardize whitespace
hot100_radio_streaming_sales["english_lyrics"] = hot100_radio_streaming_sales["english_lyrics"].str.replace(r"(\s[, | ' | \? | \! | \. | \-]+)", " ")  #delete hanging punctuation

##count number of english lyrics and total lyrics
hot100_radio_streaming_sales['english_count'] = [len(lyr.split(" ")) for lyr in hot100_radio_streaming_sales['english_lyrics']]
hot100_radio_streaming_sales['total_count'] = [len(lyr.split(" ")) for lyr in hot100_radio_streaming_sales['original_lyrics']]

##count number of unique english and total lyrics
hot100_radio_streaming_sales['english_unique'] = [len(set(lyr.split(" "))) for lyr in hot100_radio_streaming_sales['english_lyrics']]
hot100_radio_streaming_sales['total_unique'] = [len(set(lyr.split(" "))) for lyr in hot100_radio_streaming_sales['original_lyrics']]

# %%
hot100_radio_streaming_sales
# Out:
#     chart_date                                      artist  \
# 0   2019-01-12                                    Pinkfong
# 1   2009-10-31                                Wonder Girls
# 2   2012-09-22                                         Psy
# 3   2013-04-27                                         Psy
# 4   2014-06-28                        Psy feat. Snoop Dogg
# ..         ...                                         ...
# 73         NaN                                         BTS
# 74         NaN                                         BTS
# 75         NaN  K/DA: (G)I-dle & Wolftyla feat. Bea Miller
# 76         NaN                    Max Schneider feat. Suga
# 77         NaN                                    Verivery
#
#                 song_title_x  \
# 0                 Baby Shark
# 1   Nobody (English release)
# 2              Gangnam Style
# 3                  Gentleman
# 4                   Hangover
# ..                       ...
# 73                       NaN
# 74                       NaN
# 75                       NaN
# 76                       NaN
# 77                       NaN
#
#                                          Original URL  \
# 0       https://genius.com/Pinkfong-baby-shark-lyrics
# 1   https://genius.com/Wonder-girls-nobody-english...
# 2         https://genius.com/Psy-gangnam-style-lyrics
# 3             https://genius.com/Psy-gentleman-lyrics
# 4              https://genius.com/Psy-hangover-lyrics
# ..                                                ...
# 73            https://genius.com/Bts-stay-gold-lyrics
# 74       https://genius.com/Bts-your-eyes-tell-lyrics
# 75         https://genius.com/K-da-the-baddest-lyrics
# 76       https://genius.com/Max-blueberry-eyes-lyrics
# 77            https://genius.com/Verivery-gbtb-lyrics
#
#                                       original_lyrics  \
# 0   Baby shark, doo doo doo doo doo doo Baby shark...
# 1   You know I still love you baby And it will nev...
# 2   Hangul 오빤 강남 스타일 강남 스타일 낮에는 따사로운 인간적인 여자 커피 한잔...
# 3   알랑가몰라 왜 화끈해야 하는건지 알랑가몰라 왜 말끔해야 하는건지 알랑가몰라 아리까리...
# 4   Hangover, hangover, hangover, hangover-over-ov...
# ..                                                ...
# 73  Ooh ooh In a world where you feel cold You got...
# 74  何故、こんなにも 涙が溢れるの ねえ、側にいて そして笑ってよ 君のいない未来は 色のない世...
# 75  Baddest do what the baddest do (Hey) The badde...
# 76  Mmm, mmm Da-da, ooh woah-oh, yeah MAX, baby Le...
# 77  Who’s gonna pull the trigger 운명을 가를 shot No mo...
#
#                               English Translation URL  \
# 0       https://genius.com/Pinkfong-baby-shark-lyrics
# 1   https://genius.com/Wonder-girls-nobody-english...
# 2   https://genius.com/Genius-english-translations...
# 3   https://lyricstranslate.com/en/gentleman-gentl...
# 4   https://colorcodedlyrics.com/2014/06/psy-ssai-...
# ..                                                ...
# 73  https://genius.com/Genius-english-translations...
# 74  https://genius.com/Genius-english-translations...
# 75  https://genius.com/Genius-english-translations...
# 76  https://genius.com/Genius-english-translations...
# 77      https://lyricstranslate.com/en/gbtb-gbtb.html
#
#                                     translated_lyrics  peak_position  \
# 0   Baby shark, doo doo doo doo doo doo Baby shark...           32.0
# 1   You know I still love you baby And it will nev...           76.0
# 2   Oppa Gangnam Style Gangnam style Warm human wo...            2.0
# 3   I don’t know if you know why it needs to be ho...            5.0
# 4   Hangover, hangover, hangover, hangover-over-ov...           26.0
# ..                                                ...            ...
# 73  Oh, woah, oh In a world where you feel cold Yo...            NaN
# 74  Why are my eyes filled with tears? Hey, stay b...            NaN
# 75  Baddest do what the baddest do (Hey) The badde...            NaN
# 76  Mmm, mmm Da-da, ooh woah-oh, yeah MAX, baby Le...            NaN
# 77  Who's gonna pull the trigger A shot aiming for...            NaN
#
#     chart_weeks                                     english_lyrics  ...  \
# 0          20.0  Baby shark, doo doo doo doo doo doo Baby shark...  ...
# 1           1.0  You know I still love you baby And it will nev...  ...
# 2           3.0  Hangul Hey Hey Hey Hey sexy lady sexy lady Hey...  ...
# 3           1.0   We like We-we-we like party Damn, girl You so...  ...
# 4           1.0  Hangover, hangover, hangover, hangover-over-ov...  ...
# ..          ...                                                ...  ...
# 73          NaN  Ooh ooh In a world where you feel cold You got...  ...
# 74          NaN   So beautiful follow me I ll find you So color...  ...
# 75          NaN  Baddest do what the baddest do Hey The baddest...  ...
# 76          NaN  Mmm, mmm Da-da, ooh woah-oh, yeah MAX, baby Le...  ...
# 77          NaN  Who s gonna pull the trigger shot No more barr...  ...
#
#     chart_weeks_streaming  chart_date_sales    song_title_y  \
# 0                6 (R) 59               NaN             NaN
# 1                     NaN               NaN             NaN
# 2                     NaN        2012-10-06   Gangnam Style
# 3                     NaN        2013-05-04       Gentleman
# 4                     NaN               NaN             NaN
# ..                    ...               ...             ...
# 73                    NaN        2020-07-04       Stay Gold
# 74                    NaN        2020-07-25  Your Eyes Tell
# 75                    NaN        2020-09-12     The Baddest
# 76                    NaN        2020-09-26  Blueberry Eyes
# 77                    NaN        2020-10-31        G.B.T.B.
#
#     peak_position_sales  chart_weeks_sales  missing_lyrics  \
# 0                   NaN                NaN           False
# 1                   NaN                NaN           False
# 2                     1                 32           False
# 3                    20                  4           False
# 4                   NaN                NaN           False
# ..                  ...                ...             ...
# 73                    6                  1            True
# 74                   12                  1            True
# 75                   28                  1            True
# 76                   22                  1            True
# 77                   44                  1            True
#
#                 spotify_id missing_lyrics_post  english_unique total_unique
# 0   5ygDXis42ncn6kYG14lEVG               False              24           23
# 1   0TBNg82Zqi0k1VslEe2ooq               False             119          123
# 2   03UrZgTINDqvnUMbbIMhql               False              12           83
# 3   26spalP6x2gUAab8rwB8dQ               False              37           75
# 4   4ngypPwfcqpHBxQjJIOgvr               False             170          211
# ..                     ...                 ...             ...          ...
# 73  3Ys2PYl1wyPKQIwyqhP9cQ               False              41           91
# 74  3TZ7NHkMT82AhwuYsd00Hz               False              16           57
# 75  2V4Fx72svQRxrFvNT1eq5f               False             180          220
# 76  5dn6QANKbf76pANGjMBida                True              87          131
# 77  2snmVNiCZjld3lKI7BTQId                True              59          163
#
# [78 rows x 36 columns]

# %%
#### get sentiment data for all songs
from textblob import TextBlob

for i, r in hot100_radio_streaming_sales.iterrows():
    print(r['search_title'])

    eng_blob = TextBlob(r['english_lyrics'])
    print('english', eng_blob.sentiment.polarity)
    hot100_radio_streaming_sales.at[i, 'english_sentiment'] = eng_blob.sentiment.polarity

    trans_blob = TextBlob(r['translated_lyrics'])
    print('translated', trans_blob.sentiment.polarity)
    hot100_radio_streaming_sales.at[i, 'translated_sentiment'] = trans_blob.sentiment.polarity
# Out:
# Baby Shark
# english 0.25
# translated 0.25
# Nobody
# english 5.153576582148497e-05
# translated 5.153576582148497e-05
# Gangnam Style
# english 0.5
# translated 0.3921874999999999
# Gentleman
# english 0.11999999999999993
# translated 0.08669270833333328
# Hangover
# english -0.18954575517075511
# translated -0.16963059163059158
# Daddy
# english 0.48333333333333334
# translated 0.2841036414565826
# Lifted
# english -0.13373015873015875
# translated -0.13373015873015875
# DNA
# english 0.5349999999999999
# translated 0.15014880952380955
# MIC Drop
# english -0.07285889785889788
# translated -0.046976063152533776
# Fake Love
# english -0.07193877551020408
# translated 0.046141041162227586
# Ddu-Du Ddu-Du
# english -0.2954036458333333
# translated 0.13778582317073174
# Idol
# english 0.438425925925926
# translated 0.4078088578088578
# Kiss and Make Up
# english -0.17391304347826084
# translated -0.16296296296296292
# Waste It on Me
# english -0.008143939393939384
# translated -0.008143939393939384
# Kill This Love
# english 0.268031746031746
# translated 0.21606866002214836
# Boy with Luv
# english 0.45319727891156464
# translated 0.31880580357142857
# Make It Right  Make It Right remix
# english 0.2703703703703703
# translated 0.15321239606953888
# Chicken Noodle Soup
# english -0.295754716981132
# translated -0.22617187499999994
# Black Swan
# english 0.055357142857142855
# translated 0.15419501133786848
# On
# english 0.12206682206682208
# translated 0.034194158332089365
# My Time
# english 0.175
# translated 0.11397058823529412
# Filter
# english 0.3181818181818182
# translated 0.01260430390865173
# Daechwita
# english 0.8000000000000002
# translated 0.09795770202020206
# Sour Candy
# english -0.06634615384615385
# translated -0.029225288600288602
# Savage Love
# english 0.33945578231292517
# translated 0.3153439153439153
# How You Like That
# english 0.08357142857142857
# translated 0.005102040816326544
# Dynamite
# english 0.16203703703703703
# translated 0.16203703703703703
# Ice Cream
# english 0.26996753246753247
# translated 0.25454081632653064
# Lovesick Girls
# english 0.35714285714285715
# translated 0.23586601307189548
# Life Goes On
# english 0.0
# translated -0.07142857142857141
# Blue & Grey
# english 0.09166666666666666
# translated 0.03104166666666667
# Stay
# english 0.0
# translated 0.12420634920634921
# Fly to My Room
# english 0.41046717171717184
# translated 0.2732860436664786
# Telepathy
# english 0.0
# translated 0.022397563676633453
# Dis-ease
# english -0.07307256235827661
# translated -0.02772633744855968
# Pop/Stars
# english -0.12607649442755814
# translated -0.12051628211422016
# 2! 3!
# english 0.44999999999999996
# translated 0.23818452380952382
# Make It Right
# english 0.3172619047619047
# translated 0.1618871252204585
# Make It Right remix
# english 0.2703703703703703
# translated 0.15321239606953888
# Mikrokosmos
# english 0.35
# translated 0.27343749999999994
# Home
# english 0.32285714285714284
# translated 0.23326330532212886
# Dionysus
# english 0.15624999999999997
# translated -0.18926332288401246
# Jamais Vu
# english 0.09999999999999999
# translated 0.05452380952380952
# Intro: Persona
# english 0.35000000000000003
# translated 0.1550595238095238
# Dream Glow
# english 0.17071428571428568
# translated 0.18936507936507935
# A Brand New Day
# english 0.1993506493506493
# translated 0.17190082644628096
# All Night
# english 0.26571428571428574
# translated 0.25420634920634916
# Heartbeat
# english 0.28939393939393937
# translated 0.2359848484848485
# Lights
# english 0.38024691358024704
# translated 0.34577471139971155
# Suga's Interlude
# english 0.41
# translated 0.17645398080180688
# Winter Flower
# english 0.05
# translated -0.08333333333333336
# Friends
# english -0.25
# translated -0.03452861952861953
# Louder Than Bombs
# english 0.14
# translated 0.0958333333333333
# Inner Child
# english 0.0
# translated 0.12517361111111114
# We Are Bulletproof: The Eternal
# english 0.1
# translated 0.14107142857142857
# Ugh!
# english 0.0
# translated 0.08257575757575758
# 00:00
# english 0.7
# translated 0.2075400746596399
# Moon
# english 0.35
# translated 0.16030505952380955
# Interlude: Shadow
# english 0.333816425120773
# translated 0.19048850574712645
# Outro: Ego
# english 0.30255102040816334
# translated 0.1476803751803752
# Respect
# english 0.0
# translated 0.14012974330357142
# Who
# english -0.09553571428571428
# translated -0.09553571428571428
# Sweet Night
# english 0.2771604938271605
# translated 0.2771604938271605
# Eight
# english 0.3000000000000001
# translated 0.24917695473251025
# Strange
# english -0.3125
# translated 0.04493321718931474
# Burn It
# english -0.525
# translated -0.04517543859649122
# What Do You Think?
# english 0.14761904761904762
# translated 0.0031446540880503285
# Moonlight
# english 0.32
# translated 0.08084268004722554
# People
# english -0.3333333333333333
# translated 0.055715455715455726
# 28
# english -0.2
# translated 0.05729166666666667
# Dear My Friend
# english 0.0
# translated -0.11517857142857145
# Interlude: Set Me Free
# english 0.39999999999999997
# translated 0.3384615384615384
# Honsool
# english -0.4
# translated -0.0190814393939394
# Stay Gold
# english -0.07500000000000001
# translated 0.13035714285714287
# Your Eyes Tell
# english 0.575
# translated 0.2318181818181818
# The Baddest
# english -0.09190559440559437
# translated -0.11170354337020999
# Blueberry Eyes
# english 0.45999999999999996
# translated 0.12142857142857141
# G.B.T.B.
# english 0.06704545454545455
# translated 0.06956565656565655

# %%
#write to csv
#radio.to_csv('subcharts - Radio_Kpop.csv')
#streaming.to_csv('subcharts - Streaming_Kpop.csv')
#sales.to_csv('subcharts - Sales_Kpop.csv')
hot100_radio_streaming_sales.to_csv('hot100_radio_streaming_sales_Kpop.csv')
