# %%
import pandas as pd
from datetime import timedelta
from datetime import datetime
import numpy as np
import matplotlib.pyplot as plt
from textblob import TextBlob

# %%
#function to convert strings to dates :)
def string_to_datetime(string):
    result = datetime.strptime(string, "%Y-%m-%d")       
    return result

# %%
lyrics_data = pd.read_csv('Spotify_WDSS_Kpop.csv', converters={'chart_date':string_to_datetime})
#drop old index rows
lyrics_data.drop(['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.1.1'], axis=1, inplace=True)

##mark whether song has original, translated lyrics and spotify data, and which have all of them
lyrics_data['has_translation'] = [True if type(t) == type('s') else False for t in lyrics_data['translated_lyrics'] ]
lyrics_data['has_original'] = [True if type(t) == type('s') else False for t in lyrics_data['original_lyrics'] ]
lyrics_data['has_spotify'] = [True if t >= 0 else False for t in lyrics_data['valence'] ]
lyrics_data['has_all'] = [True if r['has_translation'] and r['has_original'] and r['has_spotify'] else False for i, r in lyrics_data.iterrows()]

##locate songs that have all information
complete_data = lyrics_data.loc[lyrics_data['has_all'] == True]
print('# songs with translation, original lyrics, and spotify data:', len(complete_data))
#will use this data for the rest of analysis
# Out:
# # songs with translation, original lyrics, and spotify data: 113

# %%
##process text 
#remove romanized lyrics that are in some genius pages
complete_data["original_lyrics"] = [lyrics.split("Romanization")[0] for lyrics in complete_data["original_lyrics"]]

#get rid of bracketed sections like verse indicators
complete_data["original_lyrics"] = complete_data["original_lyrics"].str.replace(r"(\[.*\])", "")
complete_data["translated_lyrics"] = complete_data["translated_lyrics"].str.replace(r"(\[.*\])", "")

#delete trailing whitespace
complete_data["original_lyrics"] = complete_data["original_lyrics"].str.strip()
complete_data["translated_lyrics"] = complete_data["translated_lyrics"].str.strip()

#clean spacing: replace all add space before llinebreaks (so theyre counted separately)
complete_data["translated_lyrics"] = complete_data["translated_lyrics"].str.replace(r"(\n+)", " \n")
complete_data["original_lyrics"] = complete_data["original_lyrics"].str.replace(r"(\n+)", " \n")

#only roman characters and white space andd punctuation
complete_data["english_lyrics"] = complete_data["original_lyrics"].str.replace(r"([^a-z | A-Z | \s | \, | \' | \? | \! | \. | \- ])", " ")
complete_data["english_lyrics"] = complete_data["english_lyrics"].str.replace(r"(\s[, | \' | \? | \! | \. | \-]+)", " ")  #delete hanging punctuation

##count number of english lyrics and total lyrics
complete_data['english_count'] = [len(lyr.split(" ")) for lyr in complete_data['english_lyrics']]
complete_data['total_count'] = [len(lyr.split(" ")) for lyr in complete_data['original_lyrics']]

#add columns for sentiment polarity for both translated and english lyrics
complete_data['translated_sentiment'] = [0.0 for i in complete_data['artist']]
complete_data['english_sentiment'] = [0.0 for i in complete_data['artist']]

complete_data
# Out:
#      Unnamed: 0.1.1.1 chart_date        artist     song_title  \
# 0                   3 2010-08-07        Shinee        Lucifer
# 10                 32 2011-08-06          2NE1           Ugly
# 11                 33 2011-08-13          2NE1  I Am the Best
# 13                 49 2011-11-19  Wonder Girls     Be My Baby
# 18                 66 2012-03-17      Big Bang        Bad Boy
# ..                ...        ...           ...            ...
# 237              1372 2020-10-17     Blackpink  Pretty Savage
# 241              1393 2020-11-14            CL            Hwa
# 242              1405 2020-12-05           BTS   Life Goes On
# 243              1406 2020-12-05           BTS    Blue & Grey
# 244              1407 2020-12-05           BTS           Stay
#
#                                        original_lyrics  \
# 0    Hangul      \n숨을 곳도 찾지 못해 나는      \n피하려고 애써 봐도...
# 10   밝게 웃어보지만      \n내 맘에 들지 않아      \n난 예쁘지 않아 아름답...
# 11   내가 제일 잘 나가      \n내가 제일 잘 나가      \n내가 제일 잘 나가...
# 13   JYP      \nAnd the Wonder Girls      \nWe're b...
# 18   Ah      \nBaby, come back      \nA-yo, Choice,...
# ..                                                 ...
# 237  Uh-huh, uh-huh      \nUh-huh, uh-huh (Prrr)   ...
# 241  Yeah, you know      \nYou want some tight tigh...
# 242  어느 날 세상이 멈췄어      \n아무런 예고도 하나 없이      \n봄은 기다...
# 243  Where is my angel?      \n하루의 끝을 드리운      \nSo...
# 244  꿈이었을까      \n널 본 것 같아      \n눈뜨면 다시      \n아무도...
#
#                                      translated_lyrics  peak_position  \
# 0    Even if I try to avoid you      \nI can't find...              3
# 10   I put a big smile on, but I don’t like how I l...              2
# 11   I am the Best      \nI am the Best      \nI am...              1
# 13   JYP      \nAnd the Wonder Girls      \nWe're b...              2
# 18   Ah...      \nBaby come back...      \nAyo choi...              3
# ..                                                 ...            ...
# 237  Uh-huh, uh-huh      \nUh-huh, uh-huh (Prrr)   ...              2
# 241  Nana Nanna Nana Nana~ (*3)      \nThe rose of ...              3
# 242  I remember      \nI, I, I remember      \nAh, ...              1
# 243  Where is my angel?      \nThe end of the day  ...              2
# 244  Oh, woah, oh      \nIn a world where you feel ...              3
#
#     entry_weeks Total\nweeks   main_artist  ...  scaled_valence  \
# 0            20           57        Shinee  ...           0.732
# 10            6            6          2NE1  ...           0.036
# 11           31          121          2NE1  ...           0.374
# 13           13           13  Wonder Girls  ...          -0.138
# 18           11           11      Big Bang  ...          -0.150
# ..          ...          ...           ...  ...             ...
# 237           2            4     Blackpink  ...          -0.236
# 241           1            1            CL  ...           0.802
# 242           1            1           BTS  ...          -0.100
# 243           1            1           BTS  ...          -0.272
# 244           1            1           BTS  ...          -0.318
#
#      has_translation  has_original  has_spotify  has_all  \
# 0               True          True         True     True
# 10              True          True         True     True
# 11              True          True         True     True
# 13              True          True         True     True
# 18              True          True         True     True
# ..               ...           ...          ...      ...
# 237             True          True         True     True
# 241             True          True         True     True
# 242             True          True         True     True
# 243             True          True         True     True
# 244             True          True         True     True
#
#                                         english_lyrics  english_count  \
# 0    Hangul        \nHer whisper is the Lucifer \nT...            121
# 10      \nOh oh oh oh \nOh oh oh oh    \nOh oh oh o...            260
# 11        Beat! \nBam, ra-ta-ta-ta, ta-ta-ta-ta-ta ...            142
# 13   JYP \nAnd the Wonder Girls \nWe're back! \nWat...            104
# 18   Ah \nBaby, come back \nA-yo, Choice, drop it o...            276
# ..                                                 ...            ...
# 237  Uh-huh, uh-huh \nUh-huh, uh-huh Prrr \nBLACKPI...            246
# 241  Yeah, you know \nYou want some tight tight pus...            627
# 242          yeah                oh    \nLike an ec...            137
# 243  Where is my angel?  \nSomeone come and save me...            115
# 244        heart  \nTogether, wherever yeah  Wherev...            149
#
#      total_count  translated_sentiment english_sentiment
# 0            892                   0.0               0.0
# 10           716                   0.0               0.0
# 11           599                   0.0               0.0
# 13           540                   0.0               0.0
# 18           824                   0.0               0.0
# ..           ...                   ...               ...
# 237          616                   0.0               0.0
# 241         1033                   0.0               0.0
# 242          593                   0.0               0.0
# 243          564                   0.0               0.0
# 244          509                   0.0               0.0
#
# [113 rows x 24 columns]

# %%
for i, r in complete_data.iterrows():
    print(r['song_title'])

    eng_blob = TextBlob(r['english_lyrics'])
    print('english', eng_blob.sentiment.polarity)
    complete_data.at[i, 'english_sentiment'] = eng_blob.sentiment.polarity

    trans_blob = TextBlob(r['translated_lyrics'])
    print('translated', trans_blob.sentiment.polarity)
    complete_data.at[i, 'translated_sentiment'] = trans_blob.sentiment.polarity
# Out:
# Lucifer
# english 0.0
# translated 0.09833539476396619
# Ugly
# english 0.04583333333333334
# translated -0.05732323232323231
# I Am the Best
# english 0.340087890625
# translated 0.5342498110355253
# Be My Baby
# english 0.325
# translated 0.1354761904761905
# Bad Boy
# english -0.14236111111111108
# translated -0.029742547425474213
# Fantastic Baby
# english 0.26666666666666666
# translated 0.08903846153846154
# Gangnam Style
# english -0.10191896226671007
# translated 0.3921874999999999
# No More Dream
# english 0.031746031746031744
# translated 0.08017625231910944
# Ringa Linga
# english 0.0987202380952381
# translated 0.19795739348370928
# Doom Dada
# english 0.028241031843973013
# translated 0.10162220026350462
# Boy in Luv
# english -0.6999999999999998
# translated -0.00197916666666665
# Eyes, Nose, Lips
# english 0.0
# translated 0.15582922824302137
# Touch My Body
# english 0.55
# translated 0.14183872767857142
# Ice Cream Cake
# english 0.3229166666666667
# translated 0.20024321556579616
# Loser
# english 0.0
# translated -0.18020993343573985
# Just Right
# english 0.09523809523809523
# translated 0.27291666666666664
# You Think
# english 0.289375
# translated 0.2186936936936937
# Lion Heart
# english 0.3571428571428571
# translated 0.12139953542392566
# Dumb Dumb
# english -0.3691588173731029
# translated -0.34070512820512816
# Run
# english 0.5
# translated 0.18350243506493508
# Hate
# english -0.26153846153846166
# translated -0.5162388392857146
# Press Your Number
# english 0.04999999999999997
# translated 0.015284178187403989
# Fly
# english 0.8000000000000003
# translated 0.4674886621315194
# Cheer Up
# english -0.00046717171717172506
# translated -0.024557032115171604
# Fire
# english 0.11386745251017638
# translated 0.03819648093841641
# Save Me
# english 0.4875
# translated 0.13525641025641028
# Epilogue: Young Forever
# english 0.09999999999999999
# translated 0.10718954248366015
# Monster
# english -0.24603174603174605
# translated -0.11711760461760463
# Fire Truck
# english 0.090625
# translated 0.02263144841269841
# Blood Sweat & Tears
# english -0.08333333333333333
# translated 0.17256493506493503
# Lie
# english 0.25
# translated 0.24058441558441562
# I Wait
# english -0.17083333333333334
# translated -0.04465811965811967
# Goodbye
# english 0.0
# translated 0.1493827160493827
# You Were Beautiful
# english 0.0
# translated 0.07346059113300493
# Spring Day
# english 1.0
# translated -0.09930555555555555
# Not Today
# english 0.16999999999999998
# translated 0.289899641798419
# A Supplementary Story: You Never Walk Alone
# english 0.8
# translated 0.22742857142857142
# How Can I Say
# english -0.1
# translated 0.06267806267806268
# Really Really
# english 0.2400000000000001
# translated 0.1807539682539683
# Cherry Bomb
# english 0.3444472789115647
# translated 0.28442414174972325
# Come Back Home
# english -0.020765027322404365
# translated -0.025416666666666653
# Ko Ko Bop
# english -0.12789351851851855
# translated -0.07698412698412703
# Gashina
# english 0.0
# translated 0.10707398661944117
# Power
# english 0.13
# translated 0.21777777777777776
# DNA
# english 0.5349999999999999
# translated 0.15014880952380955
# Intro: Serendipity
# english 0.5
# translated 0.428021978021978
# Best of Me
# english 0.8161904761904762
# translated 0.6118466898954704
# Go Go
# english 0.0
# translated 0.2533854166666666
# Peek-a-Boo
# english 0.3158333333333333
# translated 0.17135306553911203
# Crystal Snow
# english 0.33999999999999997
# translated 0.1983279683279683
# Heart Shaker
# english 0.10794177849572778
# translated 0.24261083743842365
# Heroine
# english 0.0
# translated -0.12003968253968254
# Bad Boy
# english -0.3524691358024691
# translated -0.1430555555555555
# Daydream
# english -0.02738095238095236
# translated 0.01856118791602663
# Flower Road
# english 0.5
# translated 0.14945054945054947
# Baby Don't Stop
# english 0.3523809523809524
# translated 0.256031746031746
# Boss
# english 0.34945054945054954
# translated 0.1770979020979021
# Let Go
# english 0.13026315789473686
# translated 0.14220354808590108
# What Is Love?
# english 0.04343833943833944
# translated 0.44224738675958186
# The Truth Untold
# english 0.033333333333333326
# translated 0.0036764705882352975
# Intro: Singularity
# english 0.0
# translated 0.0964285714285714
# Anpanman
# english -0.02162534435261706
# translated 0.0348614062704972
# Magic Shop
# english 0.6818181818181819
# translated 0.34704545454545455
# Dance The Night Away
# english 0.0936250901875902
# translated 0.28999999999999987
# Hann
# english 0.037500000000000006
# translated -0.04511494252873562
# Idol
# english 0.49226190476190473
# translated 0.4001594896331739
# Euphoria
# english 0.0
# translated 0.0031250000000000028
# Lullaby
# english 0.4166666666666666
# translated 0.21374999999999997
# Regular
# english 0.002328412328412329
# translated 0.2025462962962963
# Tempo
# english -0.1042222222222222
# translated 0.08009379509379513
# 2! 3!
# english 0.44999999999999996
# translated 0.23818452380952382
# Simon Says
# english 0.19595238095238096
# translated 0.20196969696969697
# RBB
# english -0.7409090909090914
# translated -0.5906111111111114
# gogobebe
# english -0.05782312925170069
# translated 0.11540616246498603
# Miroh
# english 0.4078703703703704
# translated 0.2541026461801111
# Kill This Love
# english 0.268031746031746
# translated 0.21606866002214836
# Boy with Luv
# english 0.45319727891156464
# translated 0.31880580357142857
# Mikrokosmos
# english 0.35
# translated 0.27343749999999994
# Superhuman
# english 0.3598605098605099
# translated 0.16617730095990965
# All Night
# english 0.19166666666666665
# translated 0.25420634920634916
# Heartbeat
# english 0.28939393939393937
# translated 0.2359848484848485
# Lights
# english 0.38024691358024704
# translated 0.34577471139971155
# Adios
# english -0.11818181818181818
# translated -0.07179487179487179
# Feel Special
# english 0.08581012913640029
# translated 0.3478306878306877
# Chicken Noodle Soup
# english -0.295754716981132
# translated -0.22617187499999994
# You Calling My Name
# english 0.022222222222222254
# translated 0.03893229166666668
# Hip
# english 0.11428571428571428
# translated 0.09920634920634923
# Obsession
# english 0.11130952380952382
# translated -0.06555299539170506
# 365
# english 0.0
# translated 0.10032467532467533
# Psycho
# english 0.3565393518518518
# translated 0.18548122952884857
# Winter Flower
# english 0.05
# translated -0.08333333333333336
# Black Swan
# english 0.055357142857142855
# translated 0.15419501133786848
# On
# english 0.12206682206682208
# translated 0.034194158332089365
# My Time
# english 0.175
# translated 0.11397058823529412
# Filter
# english 0.3181818181818182
# translated 0.01260430390865173
# Louder Than Bombs
# english 0.14
# translated 0.0958333333333333
# Inner Child
# english 0.0
# translated 0.12517361111111114
# We Are Bulletproof: The Eternal
# english 0.1
# translated 0.14107142857142857
# Ugh!
# english 0.0
# translated 0.08257575757575758
# Moon
# english 0.35
# translated 0.16030505952380955
# Kick It
# english 0.014318181818181808
# translated 0.07446820815868435
# Oh My God
# english 0.14642857142857144
# translated 0.09089065255731921
# More & More
# english 0.02621615783410139
# translated 0.40284090909090914
# Stay Gold
# english -0.07500000000000001
# translated 0.13035714285714287
# How You Like That
# english 0.08357142857142857
# translated 0.005102040816326544
# Your Eyes Tell
# english 0.575
# translated 0.2318181818181818
# Back Door
# english 0.15816326530612246
# translated 0.04825227963525834
# Lovesick Girls
# english 0.35714285714285715
# translated 0.23586601307189548
# Pretty Savage
# english 0.08758169934640525
# translated 0.07219982078853047
# Hwa
# english -0.03670126170126163
# translated 0.2606107660455486
# Life Goes On
# english 0.0
# translated -0.07142857142857141
# Blue & Grey
# english 0.09166666666666666
# translated 0.03104166666666667
# Stay
# english 0.0
# translated 0.13035714285714287
